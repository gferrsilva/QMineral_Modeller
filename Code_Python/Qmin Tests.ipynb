# %%
import qmin as qmin

model = qmin.load_model()

# %%
# Teste Evandro
qmin.test_cprm_datasets('../data_test/evandro_output.csv')
# Out:
# Data not in trained RF Model:  Unnamed: 0
# Data not in trained RF Model:  SAMPLE
# Data not in trained RF Model:  MINERAL
# Data not in trained RF Model:  value
# Data not in trained RF Model:  GROUP
# Data not in trained RF Model:  Total
# Data not in trained RF Model:  Pt
# Data not in trained RF Model:  Au
# Data not in trained RF Model:  Ag
# Data not in trained RF Model:  H20
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done  50 out of  50 | elapsed:    0.0s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done  50 out of  50 | elapsed:    0.0s finished
#      Unnamed: 0                    SAMPLE     MINERAL       value    GROUP  \
# 0             1               Come Quieto      PYRITE      PYRITE  SULFIDE
# 1             2                 Escorpião      PYRITE      PYRITE  SULFIDE
# 2             3                  Valdette      PYRITE      PYRITE  SULFIDE
# 3             4              Mãe de Leite      PYRITE      PYRITE  SULFIDE
# 4             5                    Galena      PYRITE      PYRITE  SULFIDE
# ..          ...                       ...         ...         ...      ...
# 265         266   GUUD-206-14_C1_Sulf-6-1  SPHALERITE  SPHALERITE  SULFIDE
# 266         267   GUUD-206-14_C1_Sulf-6-2  SPHALERITE  SPHALERITE  SULFIDE
# 267         268   GUUD-206-14_C1_Sulf-7-1  SPHALERITE  SPHALERITE  SULFIDE
# 268         269   GUUD-206-14_C1_Sulf-7-2  SPHALERITE  SPHALERITE  SULFIDE
# 269         270  GUUD-206-14_C1_Sulf-12-1  SPHALERITE  SPHALERITE  SULFIDE
#
#       Total       COO       NIO       CUO        ZNO  ...  CL  TIO2  \
# 0    99.520  0.068101  0.012726  0.012519   0.000000  ...   0     0
# 1    99.180  0.068101  0.000000  0.025038   0.012447  ...   0     0
# 2    99.310  0.068101  0.012726  0.012519   0.024894  ...   0     0
# 3    99.970  0.054481  0.000000  0.012519   0.012447  ...   0     0
# 4    97.030  0.068101  0.000000  0.012519   0.012447  ...   0     0
# ..      ...       ...       ...       ...        ...  ...  ..   ...
# 265  95.376  0.182512  0.000000  0.007511  66.726413  ...   0     0
# 266  94.221  0.182512  0.000000  0.035053  64.724919  ...   0     0
# 267  96.098  0.197494  0.000000  0.130195  67.237989  ...   0     0
# 268  95.487  0.171615  0.000000  0.255383  67.042569  ...   0     0
# 269  95.386  0.224734  0.000000  0.000000  67.196913  ...   0     0
#
#           FEOT  P2O5  H20  ZRO2  K2O  F  GROUP_ClASS  MINERAL_CLASS
# 0    66.597568     0    0     0    0  0      SULFIDE         PYRITE
# 1    64.427861     0    0     0    0  0      SULFIDE         PYRITE
# 2    66.404091     0    0     0    0  0      SULFIDE         PYRITE
# 3    65.948038     0    0     0    0  0      SULFIDE         PYRITE
# 4    65.174129     0    0     0    0  0      SULFIDE         PYRITE
# ..         ...   ...  ...   ...  ... ..          ...            ...
# 265   9.823107     0    0     0    0  0      SULFIDE     SPHALERITE
# 266   8.959370     0    0     0    0  0      SULFIDE     SPHALERITE
# 267  10.022112     0    0     0    0  0      SULFIDE     SPHALERITE
# 268   9.689055     0    0     0    0  0      SULFIDE     SPHALERITE
# 269  10.215589     0    0     0    0  0      SULFIDE     SPHALERITE
#
# [270 rows x 33 columns]
#               precision    recall  f1-score   support
#
#     AIKINITE       0.00      0.00      0.00         1
# ARSENOPYRITE       1.00      1.00      1.00        22
#      BORNITE       0.00      0.00      0.00         0
# CHALCOPYRITE       1.00      1.00      1.00        42
#    COBALTITE       1.00      1.00      1.00         3
#     DIGENITE       0.00      0.00      0.00         2
#       GALENA       1.00      0.64      0.78        11
#  GUANGLINITE       0.00      0.00      0.00         0
#     IRARSITE       0.00      0.00      0.00         0
#       PYRITE       1.00      0.96      0.98       155
#   PYRRHOTITE       0.78      1.00      0.88        18
#    RASVUMITE       0.00      0.00      0.00         0
#   SPHALERITE       1.00      1.00      1.00        16
#
#     accuracy                           0.95       270
#    macro avg       0.52      0.51      0.51       270
# weighted avg       0.97      0.95      0.96       270
#
# 0.9518518518518518
# /Users/marcosferreira/anaconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/marcosferreira/anaconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
#Teste Anderson
qmin.test_cprm_datasets('../data_test/anderson_output.csv')
# Out:
# Data not in trained RF Model:  Unnamed: 0
# Data not in trained RF Model:  id
# Data not in trained RF Model:  SAMPLE
# Data not in trained RF Model:  MINERAL
# Data not in trained RF Model:  value
# Data not in trained RF Model:  POINT
# Data not in trained RF Model:  H2O
# Data not in trained RF Model:  H20
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done  50 out of  50 | elapsed:    0.0s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done  50 out of  50 | elapsed:    0.0s finished
#      Unnamed: 0   id     SAMPLE     MINERAL       value  \
# 0             1    1  Mb-R-012A  SPHALERITE  SPHALERITE
# 1             2    2  Mb-R-012A  SPHALERITE  SPHALERITE
# 2             3    3  Mb-R-012A  SPHALERITE  SPHALERITE
# 3             4    4  Mb-R-012A  SPHALERITE  SPHALERITE
# 4             5    5  Mb-R-012A  SPHALERITE  SPHALERITE
# ..          ...  ...        ...         ...         ...
# 157         158  158    AG-01-C  SPHALERITE  SPHALERITE
# 158         159  159    AG-01-C      GALENA      GALENA
# 159         160  160    AG-01-C      GALENA      GALENA
# 160         161  161    AG-01-C      GALENA      GALENA
# 161         162  162    AG-01-C      GALENA      GALENA
#
#                      POINT       FEOT       COO       NIO       CUO  ...  \
# 0    Mb-R-012-A_C1_ESFAL_1   9.742952  0.585671  0.000000  0.300451  ...
# 1    Mb-R-012-A_C1_ESFAL_2  10.019348  0.626532  0.000000  0.087631  ...
# 2    Mb-R-012-A_C1_ESFAL_3  10.585959  0.735494  0.000000  0.012519  ...
# 3    Mb-R-012-A_C1_ESFAL_4   9.245439  0.572051  0.000000  0.137707  ...
# 4    Mb-R-012-A_C1_ESFAL_5  10.447761  0.653773  0.012726  0.212819  ...
# ..                     ...        ...       ...       ...       ...  ...
# 157       AG-01-C_C1_SPH_5   1.091763  0.000000  0.000000  0.000000  ...
# 158        AG-01-C_C1_GN_6   0.013820  0.000000  0.000000  0.012519  ...
# 159        AG-01-C_C1_GN_7   0.000000  0.000000  0.000000  0.037556  ...
# 160        AG-01-C_C1_GN_8   0.013820  0.000000  0.000000  0.012519  ...
# 161        AG-01-C_C1_GN_9   0.000000  0.013620  0.000000  0.012519  ...
#
#      NA2O  P2O5  H2O  F  CL  ZRO2  CR2O3  H20  GROUP_ClASS  MINERAL_CLASS
# 0       0     0    0  0   0     0      0    0      SULFIDE     SPHALERITE
# 1       0     0    0  0   0     0      0    0      SULFIDE     SPHALERITE
# 2       0     0    0  0   0     0      0    0      SULFIDE     SPHALERITE
# 3       0     0    0  0   0     0      0    0      SULFIDE     SPHALERITE
# 4       0     0    0  0   0     0      0    0      SULFIDE     SPHALERITE
# ..    ...   ...  ... ..  ..   ...    ...  ...          ...            ...
# 157     0     0    0  0   0     0      0    0      SULFIDE     SPHALERITE
# 158     0     0    0  0   0     0      0    0      SULFIDE       IRARSITE
# 159     0     0    0  0   0     0      0    0      SULFIDE         GALENA
# 160     0     0    0  0   0     0      0    0      SULFIDE       IRARSITE
# 161     0     0    0  0   0     0      0    0      SULFIDE         GALENA
#
# [162 rows x 31 columns]
#               precision    recall  f1-score   support
#
#           34       0.00      0.00      0.00         1
#           35       0.00      0.00      0.00         1
#           36       0.00      0.00      0.00         1
#           37       0.00      0.00      0.00         1
#           38       0.00      0.00      0.00         1
#           39       0.00      0.00      0.00         1
#           40       0.00      0.00      0.00         1
#           41       0.00      0.00      0.00         1
#   ALABANDITE       0.00      0.00      0.00         0
# ARSENOPYRITE       0.00      0.00      0.00         4
# CALCHOPYRITE       0.00      0.00      0.00        17
# CHALCOPYRITE       0.00      0.00      0.00         0
#    COBALTITE       0.00      0.00      0.00         0
#       GALENA       1.00      0.43      0.60        86
#     IRARSITE       0.00      0.00      0.00         0
#    LINNAEITE       0.00      0.00      0.00         0
#  MOLYBDENITE       0.00      0.00      0.00         0
#    NICKELINE       0.00      0.00      0.00         0
#  PENTLANDITE       0.00      0.00      0.00         0
#   POLYDYMITE       0.00      0.00      0.00         0
#       PYRITE       0.83      1.00      0.91        20
#   SPHALERITE       0.96      1.00      0.98        27
#
#     accuracy                           0.52       162
#    macro avg       0.13      0.11      0.11       162
# weighted avg       0.79      0.52      0.60       162
#
# 0.5185185185185185
# /Users/marcosferreira/anaconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/marcosferreira/anaconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# Dados Renato
#filename = '../data_othersources/EXMPLO_RESULTADOS_EPMA_MINERAIS_VARIADOS.csv'
filename = '../data_othersources/ALBITA_STANDARD_BAD_ANALYSIS.csv'
#filename = '../data_othersources/ALBITA_STANDARD_GOOD_ANALYSIS.csv'

qmin.load_data_ms(filename,separator_diferent=False)
# Out:
# /Users/marcosferreira/Documents/CPRM/2020/Qmin/QMineral_Modeller/Code_Python/qmin.py:176: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   df = pd.read_csv(filename, skipfooter=6, skiprows=3, )
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done  50 out of  50 | elapsed:    0.0s finished
#       No.      Na2O       F          MgO        Al2O3      SiO2       Cl      \
# 0        1      11.44          0       0.02      18.88      66.51       0.01
#
#       P2O5       K2O        CaO        TiO2       Cr2O3      MnO     \
# 0       0.01       0.24       0.21       0.01       0.01       0.02
#
#       V2O3       FeO        NiO       Total               Comment    \
# 0          0       0.04          0      97.42  Albita_padrao_teste
#
#   GROUP PREDICTED MINERAL PREDICTED
# 0        FELDSPAR            ALBITE
# ../data_othersources/ALBITA_STANDARD_BAD_ANALYSIS_classify.csv
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done  50 out of  50 | elapsed:    0.0s finished

# %%
# Dados Cofrinho
#filename = "../data_test/01_10_12_GRANADAS_MASSA.xls"
filename = "../data_test/01_10_12_MICAS_MASSA.xls"
#filename = "../data_test/01_10_12_PLAGIOCLASIO_MASSA.xls"

qmin.load_data_ms(filename,separator_diferent=False)
# Out:
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done  50 out of  50 | elapsed:    0.0s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done  50 out of  50 | elapsed:    0.0s finished
# /Users/marcosferreira/Documents/CPRM/2020/Qmin/QMineral_Modeller/Code_Python/qmin.py:207: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['MINERAL PREDICTED'] = predictions
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done  50 out of  50 | elapsed:    0.0s finished
# /Users/marcosferreira/Documents/CPRM/2020/Qmin/QMineral_Modeller/Code_Python/qmin.py:207: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['MINERAL PREDICTED'] = predictions
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done  50 out of  50 | elapsed:    0.0s finished
# /Users/marcosferreira/Documents/CPRM/2020/Qmin/QMineral_Modeller/Code_Python/qmin.py:207: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['MINERAL PREDICTED'] = predictions
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done  50 out of  50 | elapsed:    0.0s finished
# /Users/marcosferreira/Documents/CPRM/2020/Qmin/QMineral_Modeller/Code_Python/qmin.py:207: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['MINERAL PREDICTED'] = predictions
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
#        No.      F          Na2O       MgO        SiO2       Al2O3      CaO     \
# 0         2      0.241      0.233     13.281     36.588     18.640      0.028
# 1         3      0.312      0.202     13.268     36.483     18.903      0.016
# 2         4      0.188      0.227     12.815     36.727     19.612      0.021
# 3         5      0.117      0.257     12.851     36.626     19.631      0.000
# 4         6      0.000      1.422      0.569     45.883     35.762      0.000
# ..      ...        ...        ...        ...        ...        ...        ...
# 86       13      0.000      9.459      0.008     60.993     23.795      5.358
# 87       56      0.000      0.026     11.326     24.479     22.899      0.000
# 88       59      0.000      0.000      4.452     37.845     21.755      2.273
# 89       62      0.189      0.021      7.761     23.290     23.069      0.019
# 90       63      3.916      0.046      0.015      0.000      0.000     62.309
#
#        K2O        Cl         TiO2    ...     FeO        MnO        V2O3    \
# 0       8.621      0.001      1.719  ...     15.940      0.000      0.141
# 1       8.667      0.012      1.799  ...     15.796      0.036      0.128
# 2       8.696      0.014      1.731  ...     15.397      0.000      0.104
# 3       8.601      0.003      1.913  ...     15.589      0.062      0.022
# 4       8.801      0.009      0.912  ...      1.060      0.038      0.085
# ..        ...        ...        ...  ...        ...        ...        ...
# 86      0.083      0.003      0.000  ...      0.173      0.000      0.000
# 87      0.016      0.001      0.016  ...     32.244      0.144      0.022
# 88      0.000      0.000      0.000  ...     33.956      1.044      0.000
# 89      0.000      0.000      0.024  ...     35.589      0.370      0.011
# 90      0.000      0.000      0.000  ...      0.064      0.057      0.001
#
#        (OH)      Total          Comment   Unnamed: 17 Unnamed: 18  \
# 0       4.535    100.001  03E3 C4 BIO1 N          NaN         NaN
# 1       4.476     99.999  03E3 C4 BIO1 B          NaN         NaN
# 2       4.484    100.000  03E3 C4 BIO2 N          NaN         NaN
# 3       4.312    100.001  03E3 C4 BIO2 B          NaN         NaN
# 4       5.369     99.998   03E3 C4 MS1 N          NaN         NaN
# ..        ...        ...              ...         ...         ...
# 86      0.099    100.000    03L2 C5 MS B          NaN         NaN
# 87      8.777    100.002   1002 C1 VCL 3            B         NaN
# 88      0.000    101.325   1002 C1 BIO 6            B         NaN
# 89      9.737    100.000    1002 C1 BIO9            N         NaN
# 90     35.242    100.001    1002 C1 MS10            N         NaN
#
#    GROUP PREDICTED MINERAL PREDICTED
# 0             MICA           BIOTITE
# 1             MICA           BIOTITE
# 2             MICA           BIOTITE
# 3             MICA           BIOTITE
# 4             MICA         MUSCOVITE
# ..             ...               ...
# 86        FELDSPAR        OLIGOCLASE
# 87         OLIVINE          FAYALITE
# 88          GARNET         ALMANDINE
# 89          GARNET         ALMANDINE
# 90       CARBONATE           CALCITE
#
# [91 rows x 21 columns]
# ../data_test/01_10_12_MICAS_MASSA_classify.csv
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done  50 out of  50 | elapsed:    0.0s finished
# /Users/marcosferreira/Documents/CPRM/2020/Qmin/QMineral_Modeller/Code_Python/qmin.py:207: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['MINERAL PREDICTED'] = predictions

# %%
import glob
path_files = '../data_test/'
input_files = glob.glob(path_files + "*.xls")

for data in input_files:
    print(data)

    qmin.load_data_ms(data,separator_diferent=False)
# Out:
# ../data_test/30_10_12_GRANADAS_MASSA.xls
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done  50 out of  50 | elapsed:    0.0s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done  50 out of  50 | elapsed:    0.0s finished
# /Users/marcosferreira/Documents/CPRM/2020/Qmin/QMineral_Modeller/Code_Python/qmin.py:207: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['MINERAL PREDICTED'] = predictions
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done  50 out of  50 | elapsed:    0.0s finished
# /Users/marcosferreira/Documents/CPRM/2020/Qmin/QMineral_Modeller/Code_Python/qmin.py:207: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['MINERAL PREDICTED'] = predictions
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done  50 out of  50 | elapsed:    0.0s finished
# /Users/marcosferreira/Documents/CPRM/2020/Qmin/QMineral_Modeller/Code_Python/qmin.py:207: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['MINERAL PREDICTED'] = predictions
#         No.      Na2O       MgO        SiO2       Al2O3      K2O     \
# 0          1      0.014      5.142     37.073     21.887      0.000
# 1          2      0.020      3.634     36.586     21.410      0.000
# 2          3      0.059      6.580     33.276     20.286      0.369
# 3          4      0.021      5.017     37.315     21.566      0.000
# 4          5      0.001      4.459     37.034     21.730      0.000
# ..       ...        ...        ...        ...        ...        ...
# 129      132      0.000      4.473     37.106     21.702      0.005
# 130      133      0.005      4.065     37.167     21.729      0.008
# 131      134      0.028      3.018     36.815     21.546      0.002
# 132       20      0.067      2.674     36.473     21.329      0.403
# 133       92      7.709      0.000     58.521     24.632      0.022
#
#         CaO        TiO2       Cr2O3      FeO        MnO        V2O3    \
# 0        2.123      0.000      0.014     32.929      1.760      0.000
# 1        2.027      0.043      0.024     33.218      2.397      0.037
# 2        1.869      0.039      0.000     29.469      1.462      0.000
# 3        2.337      0.000      0.049     32.485      1.724      0.000
# 4        2.316      0.000      0.000     33.226      1.757      0.002
# ..         ...        ...        ...        ...        ...        ...
# 129      2.793      0.000      0.017     31.877      2.669      0.000
# 130      3.814      0.010      0.000     30.887      2.670      0.025
# 131      3.469      0.000      0.033     31.219      4.852      0.000
# 132      2.294      0.000      0.000     34.571      2.472      0.063
# 133      6.148      0.006      0.000      0.359      0.016      0.028
#
#         NiO       Total                Comment   GROUP PREDICTED  \
# 0        0.047    100.989                                 GARNET
# 1        0.016     99.412  09b5 c9 grt Line 001           GARNET
# 2        0.000     93.409  09b5 c9 grt Line 002           GARNET
# 3        0.036    100.550  09b5 c9 grt Line 003           GARNET
# 4        0.000    100.525  09b5 c9 grt Line 004           GARNET
# ..         ...        ...                    ...             ...
# 129      0.009    100.651  01E3 C1 GRT Line 018           GARNET
# 130      0.000    100.380  01E3 C1 GRT Line 019           GARNET
# 131      0.000    100.982  01E3 C1 GRT Line 020           GARNET
# 132      0.059    100.405  09b5 c9 grt Line 019             CLAY
# 133      0.018     97.459  03J2 C3 GRT Line 015         FELDSPAR
#
#     MINERAL PREDICTED
# 0           ALMANDINE
# 1           ALMANDINE
# 2           ALMANDINE
# 3           ALMANDINE
# 4           ALMANDINE
# ..                ...
# 129         ALMANDINE
# 130         ALMANDINE
# 131         ALMANDINE
# 132   MONTMORILLONITE
# 133          ANDESINE
#
# [134 rows x 17 columns]
# ../data_test/30_10_12_GRANADAS_MASSA_classify.csv
# ../data_test/30_10_12_PLAGIOCLASIO_1_MASSA.xls
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done  50 out of  50 | elapsed:    0.0s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done  50 out of  50 | elapsed:    0.0s finished
# /Users/marcosferreira/Documents/CPRM/2020/Qmin/QMineral_Modeller/Code_Python/qmin.py:207: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['MINERAL PREDICTED'] = predictions
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done  50 out of  50 | elapsed:    0.0s finished
# /Users/marcosferreira/Documents/CPRM/2020/Qmin/QMineral_Modeller/Code_Python/qmin.py:207: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['MINERAL PREDICTED'] = predictions
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done  50 out of  50 | elapsed:    0.0s finished
# /Users/marcosferreira/Documents/CPRM/2020/Qmin/QMineral_Modeller/Code_Python/qmin.py:207: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['MINERAL PREDICTED'] = predictions
#        3  Unnamed: 1  Unnamed: 2  62.637     TiO2       Al2O3      Cr2O3   \
# 0      4         NaN         NaN  63.032      0.000     23.071      0.000
# 1      7         NaN         NaN  62.221      0.035     23.256      0.010
# 2      8         NaN         NaN  62.765      0.000     23.418      0.000
# 3      9         NaN         NaN  62.495      0.000     23.324      0.000
# 4     10         NaN         NaN  62.659      0.000     23.245      0.000
# ..   ...         ...         ...     ...        ...        ...        ...
# 176  115         NaN         NaN  53.343      0.000     23.439      0.008
# 177  118         NaN         NaN  61.882      0.000     19.091      0.000
# 178  121         NaN         NaN  62.868      0.000     22.435      0.006
# 179  137         NaN         NaN  62.665      0.000     23.210      0.007
# 180  166         NaN         NaN  58.964      0.000     26.334      0.000
#
#      Fe2O3     FeO     MnO  ...     BaO        Na2O       K2O        SrO     \
# 0    30.32      0.047    0  ...      0.000      8.536      0.019      0.137
# 1    30.32      0.000    0  ...      0.000      8.296      0.139      0.000
# 2    30.32      0.066    0  ...      0.008      8.386      0.148      0.053
# 3    30.32      0.027    0  ...      0.000      8.208      0.150      0.135
# 4    30.32      0.061    0  ...      0.035      8.455      0.113      0.247
# ..     ...        ...  ...  ...        ...        ...        ...        ...
# 176  30.32      0.000    0  ...      0.015      8.095      0.095      0.000
# 177  30.32      0.000    0  ...      0.000      7.148      0.161      0.073
# 178  30.32      0.000    0  ...      0.080      8.387      0.111      0.151
# 179  30.32      0.025    0  ...      0.000      8.268      0.068      0.093
# 180  30.32      0.089    0  ...      0.000      6.272      0.018      0.167
#
#         V2O3     l    Total                  Comment    GROUP PREDICTED  \
# 0        0.000 NaN     99.271   03b5 c2 pla1 Line 001         CARBONATE
# 1        0.000 NaN     99.608   03b5 c2 pla1 Line 004         CARBONATE
# 2        0.025 NaN     99.738   03b5 c2 pla1 Line 005         CARBONATE
# 3        0.000 NaN     99.601   03b5 c2 pla1 Line 006         CARBONATE
# 4        0.000 NaN     99.380   03b5 c2 pla1 Line 007         CARBONATE
# ..         ...  ..        ...                      ...              ...
# 176      0.002 NaN     98.800  03b5 c8 pla 1 Line 009           SULFIDE
# 177      0.009 NaN     83.652  03b5 c8 pla 1 Line 012           SULFIDE
# 178      0.000 NaN     98.470  03b5 c8 pla 1 Line 015           SULFIDE
# 179      0.027 NaN     99.364  03b5 c6 pla 1 Line 001           SULFIDE
# 180      0.008 NaN     99.609    01d2 c6 pl3 Line 004           SULFIDE
#
#     MINERAL PREDICTED
# 0           CORDYLITE
# 1           WITHERITE
# 2           CORDYLITE
# 3         MCKELVEYITE
# 4           CORDYLITE
# ..                ...
# 176       GUANGLINITE
# 177       GUANGLINITE
# 178       GUANGLINITE
# 179       GUANGLINITE
# 180       GUANGLINITE
#
# [181 rows x 22 columns]
# ../data_test/30_10_12_PLAGIOCLASIO_1_MASSA_classify.csv
# ../data_test/01_10_12_MICAS_MASSA.xls
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done  50 out of  50 | elapsed:    0.0s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done  50 out of  50 | elapsed:    0.0s finished
# /Users/marcosferreira/Documents/CPRM/2020/Qmin/QMineral_Modeller/Code_Python/qmin.py:207: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['MINERAL PREDICTED'] = predictions
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done  50 out of  50 | elapsed:    0.0s finished
# /Users/marcosferreira/Documents/CPRM/2020/Qmin/QMineral_Modeller/Code_Python/qmin.py:207: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['MINERAL PREDICTED'] = predictions
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done  50 out of  50 | elapsed:    0.0s finished
# /Users/marcosferreira/Documents/CPRM/2020/Qmin/QMineral_Modeller/Code_Python/qmin.py:207: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['MINERAL PREDICTED'] = predictions
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done  50 out of  50 | elapsed:    0.0s finished
# /Users/marcosferreira/Documents/CPRM/2020/Qmin/QMineral_Modeller/Code_Python/qmin.py:207: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['MINERAL PREDICTED'] = predictions
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done  50 out of  50 | elapsed:    0.0s finished
# /Users/marcosferreira/Documents/CPRM/2020/Qmin/QMineral_Modeller/Code_Python/qmin.py:207: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['MINERAL PREDICTED'] = predictions
#        No.      F          Na2O       MgO        SiO2       Al2O3      CaO     \
# 0         2      0.241      0.233     13.281     36.588     18.640      0.028
# 1         3      0.312      0.202     13.268     36.483     18.903      0.016
# 2         4      0.188      0.227     12.815     36.727     19.612      0.021
# 3         5      0.117      0.257     12.851     36.626     19.631      0.000
# 4         6      0.000      1.422      0.569     45.883     35.762      0.000
# ..      ...        ...        ...        ...        ...        ...        ...
# 86       13      0.000      9.459      0.008     60.993     23.795      5.358
# 87       56      0.000      0.026     11.326     24.479     22.899      0.000
# 88       59      0.000      0.000      4.452     37.845     21.755      2.273
# 89       62      0.189      0.021      7.761     23.290     23.069      0.019
# 90       63      3.916      0.046      0.015      0.000      0.000     62.309
#
#        K2O        Cl         TiO2    ...     FeO        MnO        V2O3    \
# 0       8.621      0.001      1.719  ...     15.940      0.000      0.141
# 1       8.667      0.012      1.799  ...     15.796      0.036      0.128
# 2       8.696      0.014      1.731  ...     15.397      0.000      0.104
# 3       8.601      0.003      1.913  ...     15.589      0.062      0.022
# 4       8.801      0.009      0.912  ...      1.060      0.038      0.085
# ..        ...        ...        ...  ...        ...        ...        ...
# 86      0.083      0.003      0.000  ...      0.173      0.000      0.000
# 87      0.016      0.001      0.016  ...     32.244      0.144      0.022
# 88      0.000      0.000      0.000  ...     33.956      1.044      0.000
# 89      0.000      0.000      0.024  ...     35.589      0.370      0.011
# 90      0.000      0.000      0.000  ...      0.064      0.057      0.001
#
#        (OH)      Total          Comment   Unnamed: 17 Unnamed: 18  \
# 0       4.535    100.001  03E3 C4 BIO1 N          NaN         NaN
# 1       4.476     99.999  03E3 C4 BIO1 B          NaN         NaN
# 2       4.484    100.000  03E3 C4 BIO2 N          NaN         NaN
# 3       4.312    100.001  03E3 C4 BIO2 B          NaN         NaN
# 4       5.369     99.998   03E3 C4 MS1 N          NaN         NaN
# ..        ...        ...              ...         ...         ...
# 86      0.099    100.000    03L2 C5 MS B          NaN         NaN
# 87      8.777    100.002   1002 C1 VCL 3            B         NaN
# 88      0.000    101.325   1002 C1 BIO 6            B         NaN
# 89      9.737    100.000    1002 C1 BIO9            N         NaN
# 90     35.242    100.001    1002 C1 MS10            N         NaN
#
#    GROUP PREDICTED MINERAL PREDICTED
# 0             MICA           BIOTITE
# 1             MICA           BIOTITE
# 2             MICA           BIOTITE
# 3             MICA           BIOTITE
# 4             MICA         MUSCOVITE
# ..             ...               ...
# 86        FELDSPAR        OLIGOCLASE
# 87         OLIVINE          FAYALITE
# 88          GARNET         ALMANDINE
# 89          GARNET         ALMANDINE
# 90       CARBONATE           CALCITE
#
# [91 rows x 21 columns]
# ../data_test/01_10_12_MICAS_MASSA_classify.csv
# ../data_test/31_10_12_PLAGIOCLASIO_MASSA.xls
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done  50 out of  50 | elapsed:    0.0s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done  50 out of  50 | elapsed:    0.0s finished
#         No.      Na2O       MgO        SiO2       Al2O3      K2O     \
# 0          1      8.983      0.000     63.506     23.324      0.779
# 1          2      9.022      0.000     63.593     22.041      0.161
# 2          3      9.430      0.000     64.789     21.888      0.090
# 3          4      9.364      0.015     63.934     22.410      0.102
# 4          5      8.878      0.000     63.253     23.355      0.094
# ..       ...        ...        ...        ...        ...        ...
# 105      106      8.245      0.009     63.506     22.395      0.055
# 106      107      8.541      0.000     63.295     22.894      0.069
# 107      108      8.611      0.000     63.187     22.423      0.101
# 108      109      8.349      0.000     63.087     23.401      0.098
# 109      110      8.583      0.000     62.440     22.969      0.032
#
#         CaO        TiO2       Cr2O3      SrO        FeO        V2O3    \
# 0        2.847      0.000      0.033      0.105      0.043      0.034
# 1        3.352      0.031      0.000      0.196      0.046      0.000
# 2        3.238      0.000      0.022      0.050      0.020      0.000
# 3        3.441      0.000      0.044      0.119      0.023      0.013
# 4        4.680      0.001      0.000      0.102      0.041      0.000
# ..         ...        ...        ...        ...        ...        ...
# 105      4.454      0.000      0.000      0.000      0.000      0.007
# 106      4.468      0.000      0.000      0.189      0.048      0.036
# 107      4.320      0.005      0.008      0.060      0.029      0.000
# 108      4.778      0.017      0.000      0.016      0.024      0.000
# 109      4.830      0.000      0.000      0.302      0.000      0.000
#
#         BaO       Total                 Comment   GROUP PREDICTED  \
# 0        0.015     99.669  03b5 c2 pla1 Line 001         FELDSPAR
# 1        0.029     98.471  01C2 C6 PLG  Line 001         FELDSPAR
# 2        0.000     99.527  01C2 C6 PLG  Line 002         FELDSPAR
# 3        0.000     99.465  01C2 C6 PLG  Line 003         FELDSPAR
# 4        0.057    100.461  01C2 C6 PLG  Line 004         FELDSPAR
# ..         ...        ...                     ...             ...
# 105      0.073     98.744   033E3 C6 PL Line 006         FELDSPAR
# 106      0.000     99.540   033E3 C6 PL Line 007         FELDSPAR
# 107      0.043     98.787   033E3 C6 PL Line 008         FELDSPAR
# 108      0.000     99.770   033E3 C6 PL Line 009         FELDSPAR
# 109      0.051     99.207   033E3 C6 PL Line 010         FELDSPAR
#
#     MINERAL PREDICTED
# 0          OLIGOCLASE
# 1          OLIGOCLASE
# 2              ALBITE
# 3          OLIGOCLASE
# 4          OLIGOCLASE
# ..                ...
# 105        OLIGOCLASE
# 106        OLIGOCLASE
# 107        OLIGOCLASE
# 108        OLIGOCLASE
# 109        OLIGOCLASE
#
# [110 rows x 17 columns]
# ../data_test/31_10_12_PLAGIOCLASIO_MASSA_classify.csv
# ../data_test/31_10_12_MICAS_MASSA.xls
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done  50 out of  50 | elapsed:    0.0s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done  50 out of  50 | elapsed:    0.0s finished
# /Users/marcosferreira/Documents/CPRM/2020/Qmin/QMineral_Modeller/Code_Python/qmin.py:207: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['MINERAL PREDICTED'] = predictions
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done  50 out of  50 | elapsed:    0.0s finished
# /Users/marcosferreira/Documents/CPRM/2020/Qmin/QMineral_Modeller/Code_Python/qmin.py:207: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['MINERAL PREDICTED'] = predictions
#        No.      F          Na2O       MgO        SiO2       Al2O3      CaO     \
# 0         1      0.000      0.000      0.005     98.161      0.018      0.005
# 1         2      0.000      0.570      0.631     45.769     33.682      0.008
# 2         3      0.069      0.586      0.609     45.510     34.192      0.000
# 3         4      0.000      0.556      0.790     46.567     34.034      0.000
# 4         5      0.027      0.541      0.684     46.426     33.513      0.030
# 5         6      0.000      0.574      0.734     46.299     34.043      0.010
# 6         7      0.000      0.673      0.630     46.303     34.673      0.049
# 7         8      0.023      0.634      0.651     46.411     33.990      0.013
# 8         9      0.035      0.610      0.703     45.964     33.937      0.000
# 9        10      0.021      0.706      0.726     46.367     34.611      0.005
# 10       11      0.000      0.693      0.746     46.182     34.266      0.021
# 11       12      0.023      0.634      0.728     46.356     34.420      0.000
# 12       13      0.000      0.555      0.670     45.793     34.243      0.044
# 13       14      0.000      0.662      0.825     45.847     33.516      0.000
# 14       15      0.011      0.663      0.858     45.562     33.446      0.000
# 15       16      0.453      0.119     10.402     36.711     18.302      0.000
# 16       17      0.409      0.105     10.268     36.452     18.531      0.021
# 17       18      0.386      0.156     10.557     35.624     17.927      0.000
# 18       19      0.415      0.133     10.559     36.059     18.261      0.010
# 19       20      0.044      0.520      0.820     48.526     32.654      0.000
# 20       21      0.006      0.602      0.787     46.432     34.141      0.000
# 21       22      0.000      0.569      0.969     47.109     33.369      0.027
# 22       23      0.011      0.629      0.737     46.552     34.434      0.016
# 23       24      0.481      0.148     10.481     36.054     18.119      0.046
# 24       25      0.342      0.066     10.897     36.310     18.591      0.119
# 25       26      0.033      0.529      0.897     45.955     33.840      0.000
# 26       27      0.000      0.539      0.980     46.712     33.408      0.016
# 27       28      0.000      0.542      0.815     46.633     33.754      0.000
# 28       29      0.000      0.555      1.016     47.149     33.137      0.000
# 29       30      0.499      0.163     10.673     36.477     18.876      0.032
# 30       31      0.409      0.196     10.788     36.284     18.282      0.028
# 31       32      0.449      0.131     10.110     36.008     17.947      0.032
# 32       33      0.267      0.131     10.307     35.883     18.539      0.038
# 33       34      0.155      0.201     13.001     37.121     19.231      0.017
# 34       35      0.163      0.151     12.951     37.124     19.197      0.022
# 35       36      0.107      0.224     13.047     37.047     18.686      0.015
# 36       37      0.064      0.217     12.975     37.160     18.794      0.000
# 37       38      0.121      0.224     12.231     37.626     19.114      0.035
# 38       39      0.149      0.238     12.746     36.930     19.275      0.010
# 39       40      0.217      0.224     12.893     36.719     19.133      0.008
# 40       41      0.000      1.732      0.651     46.283     35.657      0.016
# 41       42      0.000      1.189      0.538     45.970     35.779      0.006
#
#        K2O        Cl         TiO2       Cr2O3      FeO        MnO     \
# 0       0.000      0.000      0.000      0.000      0.021      0.023
# 1      10.626      0.005      0.128      0.046      2.264      0.019
# 2      10.772      0.004      0.009      0.018      2.321      0.070
# 3      10.640      0.014      0.284      0.022      2.366      0.000
# 4      10.597      0.011      0.462      0.000      2.333      0.000
# 5      10.554      0.016      0.094      0.000      2.122      0.000
# 6      10.417      0.013      0.041      0.061      2.198      0.060
# 7      10.695      0.008      0.148      0.000      2.390      0.000
# 8      10.619      0.006      0.208      0.011      2.192      0.000
# 9      10.535      0.000      0.038      0.000      2.007      0.000
# 10     10.547      0.020      0.053      0.000      2.051      0.021
# 11     10.454      0.002      0.157      0.000      1.860      0.056
# 12     10.726      0.000      0.244      0.061      1.904      0.032
# 13     10.530      0.005      0.704      0.027      1.780      0.000
# 14     10.332      0.004      0.781      0.035      1.788      0.020
# 15      9.243      0.005      2.246      0.059     19.001      0.256
# 16      9.527      0.002      2.532      0.016     18.508      0.118
# 17      9.696      0.015      2.427      0.068     19.228      0.216
# 18      9.551      0.006      2.482      0.087     18.907      0.247
# 19      9.935      0.007      0.665      0.037      1.803      0.033
# 20     10.386      0.000      0.741      0.024      2.101      0.000
# 21     10.437      0.008      0.636      0.057      2.139      0.013
# 22     10.569      0.011      0.791      0.033      1.827      0.038
# 23      9.533      0.015      2.526      0.068     19.256      0.173
# 24      9.504      0.000      2.152      0.036     18.393      0.147
# 25     10.658      0.005      0.601      0.097      2.133      0.007
# 26     10.527      0.008      0.523      0.061      2.031      0.050
# 27     10.501      0.008      0.527      0.000      2.090      0.000
# 28     10.344      0.012      0.598      0.013      1.959      0.004
# 29      9.564      0.003      2.092      0.076     18.458      0.259
# 30      9.517      0.006      2.058      0.094     18.958      0.216
# 31      9.563      0.002      2.032      0.031     19.519      0.216
# 32      9.394      0.029      2.230      0.100     19.250      0.230
# 33      9.068      0.004      1.846      0.077     15.742      0.027
# 34      9.121      0.007      1.576      0.125     15.805      0.053
# 35      8.995      0.010      1.830      0.061     16.422      0.065
# 36      9.216      0.007      1.735      0.035     16.515      0.000
# 37      9.367      0.001      1.905      0.062     15.379      0.099
# 38      9.037      0.004      1.595      0.203     15.798      0.033
# 39      8.972      0.008      1.799      0.157     16.226      0.033
# 40      8.532      0.003      0.446      0.164      1.037      0.068
# 41      9.441      0.000      0.345      0.099      0.921      0.000
#
#        V2O3       (OH)      Total                Comment   GROUP PREDICTED  \
# 0       0.006      1.762    100.001       03b5 c2 bioin n           QUARTZ
# 1       0.031      6.223    100.001  01C2 C6 MSINCPLG 1.1             MICA
# 2       0.000      5.870    100.000         01C2 C6 MS1.1             MICA
# 3       0.011      4.719    100.000    01C2 C6 MSINCPLG 2             MICA
# 4       0.015      5.374    100.000        01C2 C6 MS 3.1             MICA
# 5       0.006      5.552    100.000          01C2 C5 MS 1             MICA
# 6       0.003      4.881     99.999         01C2 C5 MS 1B             MICA
# 7       0.010      5.039    100.000         01C2 C5 MS 2N             MICA
# 8       0.024      5.709    100.002         01C2 C5 MS 2B             MICA
# 9       0.059      4.934    100.000         01C2 C4 MS 1N             MICA
# 10      0.032      5.371     99.998         01C2 C4 MS 1B             MICA
# 11      0.002      5.318    100.000         01C2 C4 MS 2N             MICA
# 12      0.014      5.714    100.000         01C2 C4 MS 2B             MICA
# 13      0.058      6.047    100.000         01C2 C2 MS 1N             MICA
# 14      0.016      6.487     99.997         01C2 C2 MS 1B             MICA
# 15      0.041      3.355    100.001         01C2 C2 MS 2N             MICA
# 16      0.073      3.613    100.003         01C2 C2 MS 2B             MICA
# 17      0.054      3.810     99.998       01C2 C3 BIO1 1N             MICA
# 18      0.000      3.459    100.000       01C2 C3 BIO1 1B             MICA
# 19      0.086      4.889     99.998        01C2 C3 MS1 1N             MICA
# 20      0.014      4.770    100.001        01C2 C3 MS1 1B             MICA
# 21      0.093      4.574     99.998        01C2 C3 MS2 1N             MICA
# 22      0.009      4.351    100.001        01C2 C3 MS2 1B             MICA
# 23      0.081      3.226    100.001       01C2 C3 BIO2 1N             MICA
# 24      0.094      3.492     99.999       01C2 C3 BIO2 1B             MICA
# 25      0.064      5.196    100.000         01C2 C1 MS1 N             MICA
# 26      0.056      5.090     99.999         01C2 C1 MS1 B             MICA
# 27      0.063      5.067     99.998         01C2 C1 MS2 N             MICA
# 28      0.018      5.197     99.999         01C2 C1 MS2 B             MICA
# 29      0.027      3.012    100.000        01C2 C1 BIO1 N             MICA
# 30      0.038      3.297     99.998        01C2 C1 BIO1 B             MICA
# 31      0.076      4.074    100.001        01C2 C1 BIO2 N             MICA
# 32      0.053      3.668    100.000        01C2 C1 BIO2 N             MICA
# 33      0.076      3.497     99.997        03E3 C3 MS 1 N             MICA
# 34      0.057      3.717     99.998        03E3 C3 MS 1 B             MICA
# 35      0.074      3.467    100.003       03E3 C3 BIO 1 N             MICA
# 36      0.154      3.159    100.002       03E3 C3 BIO 1 B             MICA
# 37      0.129      3.758    100.000       03E3 C3 BIOINPL             MICA
# 38      0.055      3.990     99.999         03E3 C2 BIO N             MICA
# 39      0.114      3.588     99.998         03E3 C2 BIO B             MICA
# 40      0.050      5.363    100.001          03E3 C2 MS N             MICA
# 41      0.059      5.652     99.999          03E3 C2 MS B             MICA
#
#    MINERAL PREDICTED
# 0             QUARTZ
# 1          MUSCOVITE
# 2          MUSCOVITE
# 3          MUSCOVITE
# 4          MUSCOVITE
# 5          MUSCOVITE
# 6          MUSCOVITE
# 7          MUSCOVITE
# 8          MUSCOVITE
# 9          MUSCOVITE
# 10         MUSCOVITE
# 11         MUSCOVITE
# 12         MUSCOVITE
# 13         MUSCOVITE
# 14         MUSCOVITE
# 15           BIOTITE
# 16           BIOTITE
# 17           BIOTITE
# 18           BIOTITE
# 19         MUSCOVITE
# 20         MUSCOVITE
# 21         MUSCOVITE
# 22         MUSCOVITE
# 23           BIOTITE
# 24           BIOTITE
# 25         MUSCOVITE
# 26         MUSCOVITE
# 27         MUSCOVITE
# 28         MUSCOVITE
# 29           BIOTITE
# 30           BIOTITE
# 31           BIOTITE
# 32           BIOTITE
# 33           BIOTITE
# 34           BIOTITE
# 35           BIOTITE
# 36           BIOTITE
# 37           BIOTITE
# 38           BIOTITE
# 39           BIOTITE
# 40         MUSCOVITE
# 41         MUSCOVITE
# ../data_test/31_10_12_MICAS_MASSA_classify.csv
# ../data_test/31_10_12_GRANADAS_MASSA.xls
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done  50 out of  50 | elapsed:    0.0s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done  50 out of  50 | elapsed:    0.0s finished
# /Users/marcosferreira/Documents/CPRM/2020/Qmin/QMineral_Modeller/Code_Python/qmin.py:207: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['MINERAL PREDICTED'] = predictions
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done  50 out of  50 | elapsed:    0.0s finished
# /Users/marcosferreira/Documents/CPRM/2020/Qmin/QMineral_Modeller/Code_Python/qmin.py:207: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['MINERAL PREDICTED'] = predictions
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done  50 out of  50 | elapsed:    0.0s finished
# /Users/marcosferreira/Documents/CPRM/2020/Qmin/QMineral_Modeller/Code_Python/qmin.py:207: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['MINERAL PREDICTED'] = predictions
#        No.      Na2O       MgO        SiO2       Al2O3      K2O        CaO     \
# 0         1      8.403      0.000     56.671     21.751      0.078      3.925
# 1         2      0.000      1.600     36.102     21.091      0.000      2.441
# 2         3      0.066      2.129     36.293     21.545      0.019      2.437
# 3         4      0.060      1.875     36.206     21.229      0.000      3.184
# 4        10      0.014      4.392     36.782     21.709      0.000      2.661
# 5        11      0.000      4.719     36.925     21.578      0.000      3.354
# 6        12      0.059      3.959     36.879     21.513      0.000      3.899
# 7        13      0.011      3.397     37.152     21.395      0.000      5.315
# 8        14      0.030      2.983     36.594     21.581      0.000      5.526
# 9        15      0.028      2.865     36.681     21.473      0.006      5.373
# 10       16      0.000      2.646     36.641     21.381      0.008      5.728
# 11       17      0.019      2.193     37.891     23.152      0.040      5.372
# 12       18      0.016      2.346     36.786     21.248      0.014      6.376
# 13       19      0.037      2.510     36.639     21.575      0.000      5.810
# 14       20      0.012      2.466     36.575     21.608      0.013      5.680
# 15       21      0.000      2.618     36.703     21.524      0.000      5.478
# 16       22      0.015      3.163     36.950     21.412      0.000      4.887
# 17       23      0.000      3.235     37.061     21.651      0.000      4.772
# 18       24      0.002      3.580     36.690     21.362      0.000      4.336
# 19       25      0.040      3.691     36.850     21.633      0.000      4.225
# 20       26      0.019      4.291     37.013     21.577      0.000      3.920
# 21       27      0.051      4.694     37.120     21.604      0.014      3.557
# 22       28      0.000      4.703     37.128     21.588      0.000      3.092
# 23       29      0.012      4.000     36.852     21.675      0.000      2.542
# 24        5      0.046      0.023      0.000      0.000      0.000     51.926
# 25        6      0.067      0.000      0.030      0.043      0.000     51.709
# 26        7      0.044      0.000      0.059      0.000      0.000     51.219
# 27        8      0.067      0.031      0.000      0.000      0.007     51.592
# 28        9      0.000      0.000      0.000      0.000      0.006     51.466
#
#        TiO2       Cr2O3      FeO        MnO        V2O3       NiO     \
# 0       0.000      0.003      0.000      0.000      0.000      0.016
# 1       0.000      0.030     26.958     11.579      0.020      0.000
# 2       0.000      0.000     27.071     10.945      0.000      0.010
# 3       0.023      0.050     27.177     10.570      0.004      0.030
# 4       0.000      0.026     33.088      1.674      0.043      0.000
# 5       0.000      0.060     32.577      1.244      0.012      0.016
# 6       0.000      0.045     32.242      1.394      0.041      0.016
# 7       0.000      0.091     30.883      2.088      0.007      0.028
# 8       0.000      0.034     30.070      2.760      0.059      0.000
# 9       0.042      0.001     30.015      3.101      0.029      0.000
# 10      0.006      0.061     29.832      3.454      0.000      0.049
# 11      0.000      0.000     26.419      4.005      0.000      0.011
# 12      0.056      0.058     29.047      3.993      0.044      0.000
# 13      0.035      0.060     29.666      4.037      0.049      0.012
# 14      0.020      0.030     29.310      4.609      0.081      0.009
# 15      0.000      0.069     30.407      3.916      0.098      0.000
# 16      0.000      0.072     30.063      3.601      0.056      0.000
# 17      0.003      0.048     30.617      3.599      0.009      0.000
# 18      0.049      0.053     30.645      3.221      0.048      0.060
# 19      0.000      0.000     31.006      2.688      0.000      0.000
# 20      0.000      0.035     31.267      2.129      0.023      0.019
# 21      0.000      0.069     32.019      1.546      0.013      0.000
# 22      0.000      0.077     32.370      1.380      0.002      0.000
# 23      0.000      0.005     33.627      1.967      0.055      0.000
# 24      0.000      0.019      0.026      0.075      0.017      0.002
# 25      0.000      0.000      0.051      0.168      0.000      0.000
# 26      0.000      0.016      0.036      0.105      0.068      0.021
# 27      0.000      0.018      0.002      0.130      0.000      0.000
# 28      0.000      0.024      0.039      0.146      0.020      0.032
#
#       Total                 Comment   GROUP PREDICTED MINERAL PREDICTED
# 0      90.847                                FELDSPAR          ANDESINE
# 1      99.821  01C2 C3 GND1 Line 001           GARNET         ALMANDINE
# 2     100.515  01C2 C3 GND1 Line 002           GARNET         ALMANDINE
# 3     100.408  01C2 C3 GND1 Line 003           GARNET         ALMANDINE
# 4     100.389   03E3 C3 GND Line 001           GARNET         ALMANDINE
# 5     100.485   03E3 C3 GND Line 002           GARNET         ALMANDINE
# 6     100.047   03E3 C3 GND Line 003           GARNET         ALMANDINE
# 7     100.367   03E3 C3 GND Line 004           GARNET         ALMANDINE
# 8      99.637   03E3 C3 GND Line 005           GARNET         ALMANDINE
# 9      99.614   03E3 C3 GND Line 006           GARNET         ALMANDINE
# 10     99.806   03E3 C3 GND Line 007           GARNET         ALMANDINE
# 11     99.102   03E3 C3 GND Line 008           GARNET         ALMANDINE
# 12     99.984   03E3 C3 GND Line 009           GARNET         ALMANDINE
# 13    100.430   03E3 C3 GND Line 010           GARNET         ALMANDINE
# 14    100.413   03E3 C3 GND Line 011           GARNET         ALMANDINE
# 15    100.813   03E3 C3 GND Line 012           GARNET         ALMANDINE
# 16    100.219   03E3 C3 GND Line 013           GARNET         ALMANDINE
# 17    100.995   03E3 C3 GND Line 014           GARNET         ALMANDINE
# 18    100.046   03E3 C3 GND Line 015           GARNET         ALMANDINE
# 19    100.133   03E3 C3 GND Line 016           GARNET         ALMANDINE
# 20    100.293   03E3 C3 GND Line 017           GARNET         ALMANDINE
# 21    100.687   03E3 C3 GND Line 018           GARNET         ALMANDINE
# 22    100.340   03E3 C3 GND Line 019           GARNET         ALMANDINE
# 23    100.735   03E3 C3 GND Line 020           GARNET         ALMANDINE
# 24     52.134  01C2 C3 GND2 Line 001        CARBONATE           CALCITE
# 25     52.068  01C2 C3 GND2 Line 002        CARBONATE           CALCITE
# 26     51.568  01C2 C3 GND2 Line 003        CARBONATE           CALCITE
# 27     51.847  01C2 C3 GND2 Line 004        CARBONATE           CALCITE
# 28     51.733  01C2 C3 GND2 Line 005        CARBONATE           CALCITE
# ../data_test/31_10_12_GRANADAS_MASSA_classify.csv
# ../data_test/30_10_12_MICAS_MASSA.xls
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done  50 out of  50 | elapsed:    0.0s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done  50 out of  50 | elapsed:    0.0s finished
# /Users/marcosferreira/Documents/CPRM/2020/Qmin/QMineral_Modeller/Code_Python/qmin.py:207: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['MINERAL PREDICTED'] = predictions
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done  50 out of  50 | elapsed:    0.0s finished
# /Users/marcosferreira/Documents/CPRM/2020/Qmin/QMineral_Modeller/Code_Python/qmin.py:207: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['MINERAL PREDICTED'] = predictions
#        No.      F          Na2O       MgO        SiO2       Al2O3      CaO     \
# 0         1      0.133      0.250     11.874     36.842     18.991      0.016
# 1         2      0.172      0.226     11.781     37.178     18.909      0.030
# 2         3      0.222      0.346     12.690     36.952     18.974      0.055
# 3         4      0.157      0.188     12.005     36.954     19.182      0.000
# 4         5      0.000      1.195      1.005     47.173     34.030      0.044
# 5         6      0.000      1.153      1.648     46.182     33.434      0.044
# 6         7      0.000      1.257      1.037     47.010     34.079      0.053
# 7         8      0.141      0.213     11.679     36.981     18.404      0.024
# 8         9      0.000      1.291      0.919     46.820     34.628      0.004
# 9        10      0.172      0.164     11.043     36.436     18.926      0.030
# 10       11      0.183      0.187     12.208     36.735     18.839      0.014
# 11       12      0.286      0.191     12.527     37.505     19.440      0.000
# 12       13      0.182      0.147     11.734     37.114     18.946      0.032
# 13       14      0.214      0.163     11.703     36.937     18.825      0.000
# 14       15      0.262      0.119     11.580     36.960     18.817      0.027
# 15       16      0.171      0.110     11.767     37.106     19.013      0.040
# 16       17      0.215      0.573      6.697     21.669     11.098      0.180
# 17       18      0.274      0.154     11.517     36.931     19.254      0.061
# 18       19      0.284      0.796      9.893     37.532     18.875      0.483
# 19       20      0.342      0.135     11.609     36.807     18.924      0.033
# 20       21      0.200      0.197     11.673     36.914     18.367      0.024
# 21       22      0.127      0.157     11.636     36.994     18.960      0.042
# 22       24      0.020      0.566      1.092     39.683     28.914      0.083
# 23       26      0.257      0.210     11.621     36.766     19.108      0.000
# 24       27      0.261      0.185     11.534     36.814     18.903      0.008
# 25       28      0.124      0.155     12.459     36.152     19.365      0.014
# 26       29      0.241      0.165     11.407     36.885     18.908      0.038
# 27       30      0.209      0.182     11.558     36.744     18.998      0.040
# 28       31      0.195      0.236     11.544     37.294     19.307      0.000
# 29       32      0.210      0.173     12.608     36.764     18.645      0.012
# 30       33      0.263      0.211     12.514     36.580     18.763      0.100
# 31       34      0.245      0.141     12.455     37.335     19.043      0.039
# 32       35      0.105      0.183     12.340     36.934     18.946      0.043
# 33       36      0.000      0.819      0.771     46.544     35.121      0.011
# 34       37      0.000      0.664      1.212     47.387     33.731      0.000
# 35       38      0.000      0.813      0.906     46.536     34.185      0.013
# 36       39      0.000      1.116      0.752     46.423     34.074      0.050
# 37       40      0.000      1.193      0.711     45.798     33.940      0.102
# 38       41      0.000      1.037      0.561     46.588     35.170      0.018
# 39       42      0.208      0.236     12.315     36.829     19.131      0.000
# 40       43      0.164      0.253     13.103     35.428     19.386      0.025
# 41       44      0.215      0.198     12.015     36.561     19.155      0.007
# 42       45      0.201      0.214     12.422     36.598     19.282      0.013
# 43       46      0.000      1.112      0.636     46.122     34.644      0.043
# 44       23      0.000      7.352      0.000     59.503     25.476      7.291
# 45       25      0.000      4.573      0.525     54.413     29.053      3.109
#
#        K2O        Cl         TiO2       Cr2O3      FeO        MnO     \
# 0       8.984      0.016      2.527      0.077     16.603      0.037
# 1       9.178      0.029      2.543      0.035     16.613      0.023
# 2       9.066      0.041      1.770      0.084     16.743      0.040
# 3       9.009      0.014      1.853      0.084     16.880      0.000
# 4       9.138      0.009      0.802      0.093      1.115      0.000
# 5       8.913      0.018      0.841      0.060      1.813      0.044
# 6       9.322      0.004      0.926      0.043      1.109      0.000
# 7       8.861      0.000      1.913      0.014     17.254      0.000
# 8       9.140      0.004      0.694      0.000      1.095      0.048
# 9       8.997      0.030      0.890      0.040     19.600      0.009
# ...
# 32      0.083      3.749     99.999       03J2 C7 bio2.2             MICA
# 33      0.100      5.227     99.999       03J2 C7 MUSC 1             MICA
# 34      0.099      4.267    100.001       03J2 C7 MUSC 2             MICA
# 35      0.119      5.710     99.997       03J2 C7 MUSC 3             MICA
# 36      0.079      5.178    100.001        01E3 C1 MS1.1             MICA
# 37      0.085      5.673     99.998        01E3 C1 MS1.2             MICA
# 38      0.117      4.385     99.998        01E3 C1 MS1.3             MICA
# 39      0.078      2.865     99.999       01E3 C1 BIO 1N             MICA
# 40      0.105      4.241    100.001       01E3 C1 BIO 1B             MICA
# 41      0.087      3.448    100.000       01E3 C1 BIO 2N             MICA
# 42      0.048      3.943    100.003       01E3 C1 BIO 2B             MICA
# 43      0.050      5.063    100.001       01E3 C1 MUSC 1             MICA
# 44      0.000      0.154    100.000       01d2 c1 musc 1         FELDSPAR
# 45      0.003      2.302    100.000       01d2 c1 musc 3         FELDSPAR
#
#    MINERAL PREDICTED
# 0            BIOTITE
# 1            BIOTITE
# 2            BIOTITE
# 3            BIOTITE
# 4          MUSCOVITE
# 5          MUSCOVITE
# 6     HYDROMUSCOVITE
# 7            BIOTITE
# 8          MUSCOVITE
# 9            BIOTITE
# 10           BIOTITE
# 11           BIOTITE
# 12           BIOTITE
# 13           BIOTITE
# 14           BIOTITE
# 15           BIOTITE
# 16           BIOTITE
# 17           BIOTITE
# 18           BIOTITE
# 19           BIOTITE
# 20           BIOTITE
# 21           BIOTITE
# 22          SERICITE
# 23           BIOTITE
# 24           BIOTITE
# 25           BIOTITE
# 26           BIOTITE
# 27           BIOTITE
# 28           BIOTITE
# 29           BIOTITE
# 30           BIOTITE
# 31           BIOTITE
# 32           BIOTITE
# 33         MUSCOVITE
# 34         MUSCOVITE
# 35         MUSCOVITE
# 36         MUSCOVITE
# 37    HYDROMUSCOVITE
# 38         MUSCOVITE
# 39           BIOTITE
# 40           BIOTITE
# 41           BIOTITE
# 42           BIOTITE
# 43         MUSCOVITE
# 44          ANDESINE
# 45       LABRADORITE
# ../data_test/30_10_12_MICAS_MASSA_classify.csv
# ../data_test/01_10_12_PLAGIOCLASIO_MASSA.xls
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done  50 out of  50 | elapsed:    0.0s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done  50 out of  50 | elapsed:    0.0s finished
#         No.      Na2O       MgO        SiO2       Al2O3      K2O     \
# 0          2      9.426      0.015     62.031     23.833      0.063
# 1          3      9.478      0.000     62.352     23.539      0.056
# 2          4      9.743      0.000     62.694     23.492      0.065
# 3          5      9.393      0.000     62.022     23.868      0.088
# 4          6      9.973      0.000     62.387     23.421      0.038
# ..       ...        ...        ...        ...        ...        ...
# 103      105      9.482      0.000     61.125     24.009      0.054
# 104      106      9.301      0.000     60.898     23.719      0.071
# 105      107      8.964      0.000     58.602     22.860      0.061
# 106      108      9.390      0.000     60.523     23.703      0.057
# 107      109      9.554      0.000     61.041     24.183      0.031
#
#         CaO        TiO2       Cr2O3      SrO        FeO        V2O3    \
# 0        5.362      0.000      0.011      0.138      0.107      0.056
# 1        4.825      0.000      0.023      0.186      0.135      0.046
# 2        4.676      0.000      0.000      0.057      0.166      0.000
# 3        5.193      0.000      0.000      0.000      0.087      0.026
# 4        4.615      0.000      0.000      0.138      0.049      0.018
# ..         ...        ...        ...        ...        ...        ...
# 103      5.423      0.020      0.017      0.087      0.157      0.000
# 104      5.322      0.002      0.062      0.189      0.034      0.000
# 105      5.258      0.000      0.048      0.170      0.035      0.030
# 106      5.336      0.000      0.000      0.160      0.071      0.044
# 107      5.465      0.000      0.000      0.000      0.282      0.023
#
#         BaO       Total          Comment   GROUP PREDICTED MINERAL PREDICTED
# 0        0.000    101.042  03E3 C4 PLA1 1         FELDSPAR        OLIGOCLASE
# 1        0.022    100.662  03E3 C4 PLA1 2         FELDSPAR        OLIGOCLASE
# 2        0.080    100.973  03E3 C4 PLA1 3         FELDSPAR        OLIGOCLASE
# 3        0.064    100.741  03E3 C4 PLA2 1         FELDSPAR        OLIGOCLASE
# 4        0.016    100.655  03E3 C4 PLA2 2         FELDSPAR        OLIGOCLASE
# ..         ...        ...              ...             ...               ...
# 103      0.107    100.481   03L2 C6 PL2 1         FELDSPAR        OLIGOCLASE
# 104      0.008     99.606   03L2 C6 PL2 2         FELDSPAR        OLIGOCLASE
# 105      0.000     96.028   03L2 C6 PL2 3         FELDSPAR          ANDESINE
# 106      0.000     99.284   03L2 C6 PL2 4         FELDSPAR        OLIGOCLASE
# 107      0.071    100.650   03L2 C6 PL2 5         FELDSPAR        OLIGOCLASE
#
# [108 rows x 17 columns]
# ../data_test/01_10_12_PLAGIOCLASIO_MASSA_classify.csv
# ../data_test/01_10_12_GRANADAS_MASSA.xls
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done  50 out of  50 | elapsed:    0.0s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done  50 out of  50 | elapsed:    0.0s finished
# /Users/marcosferreira/Documents/CPRM/2020/Qmin/QMineral_Modeller/Code_Python/qmin.py:207: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['MINERAL PREDICTED'] = predictions
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done  50 out of  50 | elapsed:    0.0s finished
# /Users/marcosferreira/Documents/CPRM/2020/Qmin/QMineral_Modeller/Code_Python/qmin.py:207: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['MINERAL PREDICTED'] = predictions
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done  50 out of  50 | elapsed:    0.0s finished
# /Users/marcosferreira/Documents/CPRM/2020/Qmin/QMineral_Modeller/Code_Python/qmin.py:207: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['MINERAL PREDICTED'] = predictions
#        No.      Na2O       MgO        SiO2       Al2O3      K2O        CaO     \
# 0        47      0.000      4.463     36.268     21.240      0.000      2.888
# 1        48      0.026      5.146     36.607     21.358      0.033      2.856
# 2        49      0.000      4.960     36.977     21.575      0.000      2.384
# 3        50      0.039      4.958     36.536     21.571      0.018      3.035
# 4        51      0.000      4.691     36.478     21.224      0.000      3.754
# ..      ...        ...        ...        ...        ...        ...        ...
# 66       46      0.000      3.956     36.235     21.072      0.000      2.323
# 67       67      2.210      7.034     34.195     31.432      0.023      0.724
# 68       30      2.906      1.442     42.182     20.756      1.241      5.766
# 69       69      0.029      0.033      0.000      0.000      0.023     53.338
# 70        1      0.041      0.020      0.000      0.000      0.000     52.439
#
#        TiO2       Cr2O3      FeO        MnO        V2O3      Total    \
# 0       0.000      0.002     33.403      1.816      0.051    100.131
# 1       0.000      0.000     32.217      1.139      0.016     99.398
# 2       0.039      0.000     33.135      1.319      0.000    100.389
# 3       0.000      0.049     32.394      1.156      0.049     99.805
# 4       0.008      0.034     32.774      0.759      0.000     99.722
# ..        ...        ...        ...        ...        ...        ...
# 66      0.000      0.051     33.472      2.261      0.053     99.423
# 67      0.824      0.045      5.910      0.082      0.070     82.549
# 68      0.000      0.000     16.242      1.776      0.039     92.350
# 69      0.000      0.000      0.068      0.107      0.031     53.629
# 70      0.000      0.000      0.063      0.000      0.002     52.565
#
#                  Comment   GROUP PREDICTED MINERAL PREDICTED
# 0    03L2 C6 GRT Line 001           GARNET         ALMANDINE
# 1    03L2 C6 GRT Line 002           GARNET         ALMANDINE
# 2    03L2 C6 GRT Line 003           GARNET         ALMANDINE
# 3    03L2 C6 GRT Line 004           GARNET         ALMANDINE
# 4    03L2 C6 GRT Line 005           GARNET         ALMANDINE
# ..                     ...             ...               ...
# 66  03L2 C7 GRT1 Line 025           GARNET         ALMANDINE
# 67   03L2 C6 GRT Line 021       AMPHIBOLES           GEDRITE
# 68  03L2 C7 GRT1 Line 009       AMPHIBOLES     CUMMINGTONITE
# 69   03L2 C6 GRT Line 023        CARBONATE           CALCITE
# 70                               CARBONATE           CALCITE
#
# [71 rows x 16 columns]
# ../data_test/01_10_12_GRANADAS_MASSA_classify.csv
# ../data_test/30_10_12_PLAGIOCLASIO_2_MASSA.xls
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done  50 out of  50 | elapsed:    0.0s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done  50 out of  50 | elapsed:    0.0s finished
# /Users/marcosferreira/Documents/CPRM/2020/Qmin/QMineral_Modeller/Code_Python/qmin.py:207: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['MINERAL PREDICTED'] = predictions
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done  50 out of  50 | elapsed:    0.0s finished
# /Users/marcosferreira/Documents/CPRM/2020/Qmin/QMineral_Modeller/Code_Python/qmin.py:207: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['MINERAL PREDICTED'] = predictions
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done  50 out of  50 | elapsed:    0.0s finished
# /Users/marcosferreira/Documents/CPRM/2020/Qmin/QMineral_Modeller/Code_Python/qmin.py:207: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['MINERAL PREDICTED'] = predictions
#         No.      Na2O       MgO        SiO2       Al2O3      K2O     \
# 0          1      0.000      0.012     99.581      0.000      0.000
# 1          2      0.011      0.003     99.976      0.005      0.000
# 2          3      0.000      0.007    100.179      0.000      0.007
# 3          4      0.000      0.000    100.033      0.000      0.010
# 4          5      0.033      0.017     99.883      0.007      0.019
# ..       ...        ...        ...        ...        ...        ...
# 134      139      8.168      0.000     60.726     24.550      0.036
# 135       42      4.592      5.728     47.891     20.634      2.215
# 136      134      2.812      3.622     32.091     29.497      3.932
# 137      115      0.221     12.246     36.284     19.033      9.257
# 138      118      1.171      0.542     45.207     34.010      9.177
#
#         CaO        TiO2       Cr2O3      SrO        FeO        V2O3    \
# 0        0.008      0.000      0.012      0.000      0.036      0.000
# 1        0.009      0.000      0.022      0.009      0.019      0.000
# 2        0.008      0.015      0.000      0.140      0.013      0.000
# 3        0.000      0.000      0.000      0.045      0.096      0.000
# 4        0.030      0.000      0.000      0.142      0.197      0.000
# ..         ...        ...        ...        ...        ...        ...
# 134      6.263      0.001      0.000      0.007      0.097      0.000
# 135      3.154      0.029      0.000      0.148      6.801      0.029
# 136      1.048      0.568      0.000      0.000     11.089      0.065
# 137      0.021      1.412      0.022      0.001     16.403      0.086
# 138      0.000      0.495      0.035      0.000      2.252      0.048
#
#         BaO       Total                    Comment   GROUP PREDICTED  \
# 0        0.000     99.649      03j2 c4 pl1 Line 001           QUARTZ
# 1        0.000    100.054      03j2 c4 pl1 Line 002           QUARTZ
# 2        0.050    100.419      03j2 c4 pl1 Line 003           QUARTZ
# 3        0.087    100.271      03j2 c4 pl1 Line 004           QUARTZ
# 4        0.007    100.335      03j2 c4 pl1 Line 005           QUARTZ
# ..         ...        ...                        ...             ...
# 134      0.000     99.848    01E3 C04 PLAG Line 015         FELDSPAR
# 135      0.029     91.250     03j2 c2 PLAG Line 012       AMPHIBOLES
# 136      0.078     84.802    01E3 C04 PLAG Line 010       AMPHIBOLES
# 137      0.252     95.238  01E3 C06 PLAG 1 Line 004             MICA
# 138      0.437     93.374  01E3 C06 PLAG 1 Line 007             MICA
#
#     MINERAL PREDICTED
# 0              QUARTZ
# 1              QUARTZ
# 2              QUARTZ
# 3              QUARTZ
# 4              QUARTZ
# ..                ...
# 134        OLIGOCLASE
# 135        BARROISITE
# 136           GEDRITE
# 137           BIOTITE
# 138         MUSCOVITE
#
# [139 rows x 17 columns]
# ../data_test/30_10_12_PLAGIOCLASIO_2_MASSA_classify.csv
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done  50 out of  50 | elapsed:    0.0s finished
# /Users/marcosferreira/Documents/CPRM/2020/Qmin/QMineral_Modeller/Code_Python/qmin.py:207: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['MINERAL PREDICTED'] = predictions
