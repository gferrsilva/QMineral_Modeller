# %%
import numpy as np
import pandas as pd
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
import itertools
import glob
import pickle
import matplotlib.pyplot as plt
import qmin

# %%
def getTrainData(path_files):
    #Import Mineral Balanced Data!!!!
    
    input_files = glob.glob(path_files + "*.csv")

    min_in = []

    for filename in input_files:
        df = pd.read_csv(filename, index_col=None, header=0, encoding = "ISO-8859-1")
        min_in.append(df)

    df_all = pd.concat(min_in, axis=0, ignore_index=True)
    #print(df_all.columns)
    
    df = df_all.drop(columns = ['Unnamed: 0', 'X1', 'id', 'SAMPLE', 'GROUP', 'MINERAL', 'ROCK','X1_1'])
    return df, df_all

    
def test_acc(X,y, model,plot=True,modelName='rf'):
    # Function to test the accuracy
    n_nodes = []
    max_depths = []

    for ind_tree in model.estimators_:
        n_nodes.append(ind_tree.tree_.node_count)
        max_depths.append(ind_tree.tree_.max_depth)

    print(f'Average number of nodes {int(np.mean(n_nodes))}')
    print(f'Average maximum depth {int(np.mean(max_depths))}')
    
    feature_list = list(X.columns)
    # Get numerical feature importances
    importances = list(model.feature_importances_)
    # List of tuples with variable and importance
    feature_importances = [(feature, round(importance, 2)) for feature, importance in zip(feature_list, importances)]
    # Sort the feature importances by most important first
    feature_importances = sorted(feature_importances, key = lambda x: x[1], reverse = True)
    # Print out the feature and importances 
    [print('Variable: {:20} Importance: {}'.format(*pair)) for pair in feature_importances];

    y_pred = model.predict(X)
    
    #print(confusion_matrix(y,y_pred))
    cm = confusion_matrix(y, y_pred)
    if plot:
        if modelName == 'rf':
            qmin.plot_confusion_matrix(cm, classes = np.unique(y),
                                  title = 'Confusion Matrix',normalize=True)
        else:
            qmin.plot_confusion_matrix(cm, classes = np.unique(y),
                                  title = 'Confusion Matrix',normalize=True,
                                 output='../figures/rf'+modelName+'_confusion_matrix.png')
        print(classification_report(y,y_pred))
    print(accuracy_score(y, y_pred))
    return accuracy_score(y, y_pred)

def save_Model(model, model_name):
    path = '../model_py/'
    pickle.dump(model, open(path+model_name, 'wb'))
    print("Model Saved ...\n"+path+model_name)
    
def randomForestBuilder(trainData,labels, acc_test=True, saveModel=True, nameModel='RF'):
    # Separate 30% for test, training in 70% of Data!
    train, test, train_labels, test_labels = train_test_split(trainData, labels, 
                                                              stratify = labels,
                                                              test_size = 0.3)
    model = RandomForestClassifier(n_estimators=50, 
                               max_features = 'sqrt',
                               n_jobs=-1, verbose = 1,
                               oob_score=True)

    # Fit on training data
    model.fit(train, train_labels)
    
    if acc_test:
        acc = test_acc(test,test_labels,model,modelName=nameModel)
    
    if saveModel:
        save_Model(model, nameModel+'.pkl')
    
    return model, test_acc(test,test_labels,model,plot=False)

def _cleanDataFrame(df):
    df = df.drop(columns = ['Unnamed: 0', 'X1', 'id', 'SAMPLE', 'GROUP', 'ROCK','X1_1'])
    return df

def createMineralModel(data,namegroup):
    #get Dataframe to create multiple mineral models
    
    labels = labels = np.array(data.pop('MINERAL'))
    trainData = _cleanDataFrame(data)    
    mineralModel, acc = randomForestBuilder(trainData,labels,acc_test=True,
                                     saveModel=False, nameModel=namegroup)
    return mineralModel,acc
    
    

def modelCreate():
    models = {}
    
    trainData, allData = getTrainData('../data_train/')
    trainFeatures = trainData.columns
    labels = np.array(allData.pop('GROUP'))
    allData['GROUP'] = labels

    #Group Model C;assify
    groupModel, acc = randomForestBuilder(trainData,labels,acc_test=False,
                                     saveModel=True, nameModel='RF_GROUP')
    models['GROUP'] = groupModel
    
    groups = allData['GROUP'].unique() # Get all Gruops for mineral classification

    accs = []
    for group in groups:
        print('Training .... '+group)
        mineralData = allData[allData['GROUP']== group]
        models[group], acc = createMineralModel(mineralData,group)
        accs.append([group,acc])
    
    print(accs)
    return models,trainFeatures


models, trainFeatures = modelCreate()
# Out:
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-1)]: Done  50 out of  50 | elapsed:    0.1s finished
# Model Saved ...
# ../model_py/RF_GROUP.pkl
# Average number of nodes 274
# Average maximum depth 14
# Variable: SIO2                 Importance: 0.13
# Variable: H20                  Importance: 0.13
# Variable: S                    Importance: 0.1
# Variable: AL2O3                Importance: 0.08
# Variable: ZRO2                 Importance: 0.06
# Variable: CAO                  Importance: 0.05
# Variable: FEOT                 Importance: 0.04
# Variable: MGO                  Importance: 0.04
# Variable: K2O                  Importance: 0.04
# Variable: F                    Importance: 0.04
# Variable: CUO                  Importance: 0.04
# Variable: COO                  Importance: 0.04
# Variable: TIO2                 Importance: 0.03
# Variable: NA2O                 Importance: 0.03
# Variable: CL                   Importance: 0.03
# Variable: ZNO                  Importance: 0.03
# Variable: MNO                  Importance: 0.02
# Variable: NIO                  Importance: 0.02
# Variable: CR2O3                Importance: 0.01
# Variable: P2O5                 Importance: 0.01
# Variable: AS                   Importance: 0.01
# Variable: PBO                  Importance: 0.0
# [Parallel(n_jobs=4)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  42 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=4)]: Done  50 out of  50 | elapsed:    0.0s finished
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 4 concurrent workers.
# 0.9976359338061466
# Training .... AMPHIBOLES
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done  50 out of  50 | elapsed:    0.0s finished
# Average number of nodes 310
# Average maximum depth 15
# Variable: NA2O                 Importance: 0.11
# Variable: SIO2                 Importance: 0.09
# Variable: TIO2                 Importance: 0.09
# Variable: AL2O3                Importance: 0.09
# Variable: CAO                  Importance: 0.09
# Variable: FEOT                 Importance: 0.08
# Variable: MGO                  Importance: 0.07
# Variable: MNO                  Importance: 0.07
# Variable: K2O                  Importance: 0.07
# Variable: H20                  Importance: 0.05
# Variable: F                    Importance: 0.05
# Variable: CR2O3                Importance: 0.03
# Variable: P2O5                 Importance: 0.03
# Variable: CL                   Importance: 0.03
# Variable: NIO                  Importance: 0.03
# Variable: ZRO2                 Importance: 0.03
# Variable: CUO                  Importance: 0.0
# Variable: COO                  Importance: 0.0
# Variable: ZNO                  Importance: 0.0
# Variable: PBO                  Importance: 0.0
# Variable: S                    Importance: 0.0
# Variable: AS                   Importance: 0.0
# [Parallel(n_jobs=4)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  42 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=4)]: Done  50 out of  50 | elapsed:    0.0s finished
# Normalized confusion matrix
#                                 precision    recall  f1-score   support
#
#                     ACTINOLITE       0.82      1.00      0.90         9
#                  ANTHOPHYLLITE       0.90      1.00      0.95         9
#                   ARFVEDSONITE       1.00      0.56      0.71         9
#                     BARROISITE       0.89      0.89      0.89         9
#                  CUMMINGTONITE       1.00      0.78      0.88         9
#                   ECKERMANNITE       0.69      1.00      0.82         9
#                        EDENITE       0.71      0.56      0.63         9
#             FE-TI-TSCHERMAKITE       0.64      1.00      0.78         9
#             FERRI-TSCHERMAKITE       0.78      0.78      0.78         9
# FERRI-TSCHERMAKITIC HORNBLENDE       0.60      0.67      0.63         9
#               FERRICNYB<d6>ITE       0.90      1.00      0.95         9
#                FERRORICHTERITE       0.53      0.89      0.67         9
#                        GEDRITE       0.90      1.00      0.95         9
#                    GLAUCOPHANE       1.00      0.78      0.88         9
#                    HASTINGSITE       0.50      0.67      0.57         9
#                     KAERSUTITE       1.00      0.44      0.62         9
#                    KATOPHORITE       0.78      0.78      0.78         9
#           MAGNESIO-HASTINGSITE       0.71      0.56      0.63         9
#            MAGNESIO-HORNBLENDE       0.89      0.89      0.89         9
#           MAGNESIOARFVEDSONITE       0.80      0.89      0.84         9
#            MAGNESIOKATOPHORITE       0.80      0.89      0.84         9
#                  OXYKAERSUTITE       0.64      1.00      0.78         9
#                      PARGASITE       0.57      0.44      0.50         9
#                     RICHTERITE       1.00      1.00      1.00         9
#                     RIEBECKITE       0.67      0.22      0.33         9
#     TITAN-MAGNESIO-HASTINGSITE       1.00      0.78      0.88         9
#                      TREMOLITE       1.00      1.00      1.00         9
#                   TSCHERMAKITE       0.40      0.22      0.29         9
#                       WINCHITE       0.89      0.89      0.89         9
#
#                       accuracy                           0.78       261
#                      macro avg       0.79      0.78      0.77       261
#                   weighted avg       0.79      0.78      0.77       261
#
# 0.7777777777777778
# Average number of nodes 310
# Average maximum depth 15
# Variable: NA2O                 Importance: 0.11
# Variable: SIO2                 Importance: 0.09
# Variable: TIO2                 Importance: 0.09
# Variable: AL2O3                Importance: 0.09
# Variable: CAO                  Importance: 0.09
# Variable: FEOT                 Importance: 0.08
# Variable: MGO                  Importance: 0.07
# Variable: MNO                  Importance: 0.07
# Variable: K2O                  Importance: 0.07
# Variable: H20                  Importance: 0.05
# Variable: F                    Importance: 0.05
# Variable: CR2O3                Importance: 0.03
# Variable: P2O5                 Importance: 0.03
# Variable: CL                   Importance: 0.03
# Variable: NIO                  Importance: 0.03
# Variable: ZRO2                 Importance: 0.03
# Variable: CUO                  Importance: 0.0
# Variable: COO                  Importance: 0.0
# Variable: ZNO                  Importance: 0.0
# Variable: PBO                  Importance: 0.0
# Variable: S                    Importance: 0.0
# Variable: AS                   Importance: 0.0
# [Parallel(n_jobs=4)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  42 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=4)]: Done  50 out of  50 | elapsed:    0.0s finished
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 4 concurrent workers.
# 0.7777777777777778
# Training .... CARBONATE
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done  50 out of  50 | elapsed:    0.0s finished
# Average number of nodes 296
# Average maximum depth 18
# Variable: CAO                  Importance: 0.14
# Variable: NA2O                 Importance: 0.1
# Variable: MNO                  Importance: 0.09
# Variable: FEOT                 Importance: 0.08
# Variable: SIO2                 Importance: 0.07
# Variable: MGO                  Importance: 0.07
# Variable: F                    Importance: 0.07
# Variable: K2O                  Importance: 0.06
# Variable: AL2O3                Importance: 0.05
# Variable: P2O5                 Importance: 0.05
# Variable: TIO2                 Importance: 0.04
# Variable: CR2O3                Importance: 0.04
# Variable: CL                   Importance: 0.04
# Variable: NIO                  Importance: 0.03
# Variable: ZNO                  Importance: 0.03
# Variable: S                    Importance: 0.03
# Variable: ZRO2                 Importance: 0.02
# Variable: H20                  Importance: 0.0
# Variable: CUO                  Importance: 0.0
# Variable: COO                  Importance: 0.0
# Variable: PBO                  Importance: 0.0
# Variable: AS                   Importance: 0.0
# [Parallel(n_jobs=4)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  42 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=4)]: Done  50 out of  50 | elapsed:    0.0s finished
# Normalized confusion matrix
#                   precision    recall  f1-score   support
#
#        ALSTONITE       1.00      1.00      1.00         9
#         ANCYLITE       0.62      0.56      0.59         9
#         ANKERITE       0.67      0.67      0.67         9
#    BARYTOCALCITE       1.00      0.67      0.80         9
#      BREUNNERITE       1.00      0.89      0.94         9
#       BURBANKITE       0.70      0.78      0.74         9
#          CALCITE       1.00      1.00      1.00         9
#    CARBOCERNAITE       0.86      0.67      0.75         9
#          CEBAITE       0.56      0.56      0.56         9
#        CORDYLITE       0.71      0.56      0.63         9
#         DOLOMITE       0.67      0.89      0.76         9
# FLUORO-CARBONATE       0.89      0.89      0.89         9
#       GREGORYITE       0.75      1.00      0.86         9
#       HUANGHOITE       1.00      1.00      1.00         9
#      KHANNESHITE       1.00      1.00      1.00         9
#    KUKHARENKOITE       0.70      0.78      0.74         9
#      KUTNAHORITE       1.00      0.89      0.94         9
# MAGNESIOSIDERITE       0.67      0.67      0.67         9
#        MAGNESITE       0.89      0.89      0.89         9
#      MCKELVEYITE       1.00      0.78      0.88         9
#       NORSETHITE       0.80      0.89      0.84         9
#       NYEREREITE       0.90      1.00      0.95         9
#     OLEKMINSKITE       1.00      0.89      0.94         9
#       PIRSSONITE       1.00      1.00      1.00         9
#     QAQARSSUKITE       1.00      1.00      1.00         9
#    RHODOCHROSITE       1.00      1.00      1.00         9
#         SHORTITE       0.90      1.00      0.95         9
#         SIDERITE       1.00      1.00      1.00         9
#         SPURRITE       1.00      1.00      1.00         9
#     STRONTIANITE       0.45      0.56      0.50         9
#        WITHERITE       1.00      1.00      1.00         9
#
#         accuracy                           0.85       279
#        macro avg       0.86      0.85      0.85       279
#     weighted avg       0.86      0.85      0.85       279
#
# 0.8530465949820788
# Average number of nodes 296
# Average maximum depth 18
# Variable: CAO                  Importance: 0.14
# Variable: NA2O                 Importance: 0.1
# Variable: MNO                  Importance: 0.09
# Variable: FEOT                 Importance: 0.08
# Variable: SIO2                 Importance: 0.07
# Variable: MGO                  Importance: 0.07
# Variable: F                    Importance: 0.07
# Variable: K2O                  Importance: 0.06
# Variable: AL2O3                Importance: 0.05
# Variable: P2O5                 Importance: 0.05
# Variable: TIO2                 Importance: 0.04
# Variable: CR2O3                Importance: 0.04
# Variable: CL                   Importance: 0.04
# Variable: NIO                  Importance: 0.03
# Variable: ZNO                  Importance: 0.03
# Variable: S                    Importance: 0.03
# Variable: ZRO2                 Importance: 0.02
# Variable: H20                  Importance: 0.0
# Variable: CUO                  Importance: 0.0
# Variable: COO                  Importance: 0.0
# Variable: PBO                  Importance: 0.0
# Variable: AS                   Importance: 0.0
# [Parallel(n_jobs=4)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  42 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=4)]: Done  50 out of  50 | elapsed:    0.0s finished
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 4 concurrent workers.
# 0.8530465949820788
# Training .... CLAY
# Average number of nodes 81
# Average maximum depth 10
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done  50 out of  50 | elapsed:    0.0s finished
# [Parallel(n_jobs=4)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  42 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=4)]: Done  50 out of  50 | elapsed:    0.0s finished
# Variable: MGO                  Importance: 0.13
# Variable: K2O                  Importance: 0.13
# Variable: SIO2                 Importance: 0.12
# Variable: TIO2                 Importance: 0.11
# Variable: AL2O3                Importance: 0.11
# Variable: CAO                  Importance: 0.09
# Variable: FEOT                 Importance: 0.06
# Variable: MNO                  Importance: 0.05
# Variable: NA2O                 Importance: 0.04
# Variable: P2O5                 Importance: 0.04
# Variable: NIO                  Importance: 0.04
# Variable: CR2O3                Importance: 0.03
# Variable: H20                  Importance: 0.03
# Variable: CL                   Importance: 0.03
# Variable: F                    Importance: 0.0
# Variable: CUO                  Importance: 0.0
# Variable: COO                  Importance: 0.0
# Variable: ZNO                  Importance: 0.0
# Variable: PBO                  Importance: 0.0
# Variable: S                    Importance: 0.0
# Variable: ZRO2                 Importance: 0.0
# Variable: AS                   Importance: 0.0
# Normalized confusion matrix
#                  precision    recall  f1-score   support
#
#      BEIDELLITE       0.82      1.00      0.90         9
#      CORRENSITE       1.00      1.00      1.00         9
#          ILLITE       1.00      0.67      0.80         9
#       KAOLINITE       1.00      1.00      1.00         9
# MONTMORILLONITE       0.86      0.67      0.75         9
#      NONTRONITE       1.00      1.00      1.00         9
#      PALAGONITE       0.69      1.00      0.82         9
#        SAPONITE       0.70      0.78      0.74         9
#        SMECTITE       0.71      0.56      0.63         9
#
#        accuracy                           0.85        81
#       macro avg       0.86      0.85      0.85        81
#    weighted avg       0.86      0.85      0.85        81
#
# 0.8518518518518519
# Average number of nodes 81
# Average maximum depth 10
# Variable: MGO                  Importance: 0.13
# Variable: K2O                  Importance: 0.13
# Variable: SIO2                 Importance: 0.12
# Variable: TIO2                 Importance: 0.11
# Variable: AL2O3                Importance: 0.11
# Variable: CAO                  Importance: 0.09
# Variable: FEOT                 Importance: 0.06
# Variable: MNO                  Importance: 0.05
# Variable: NA2O                 Importance: 0.04
# Variable: P2O5                 Importance: 0.04
# Variable: NIO                  Importance: 0.04
# Variable: CR2O3                Importance: 0.03
# Variable: H20                  Importance: 0.03
# Variable: CL                   Importance: 0.03
# Variable: F                    Importance: 0.0
# Variable: CUO                  Importance: 0.0
# Variable: COO                  Importance: 0.0
# Variable: ZNO                  Importance: 0.0
# Variable: PBO                  Importance: 0.0
# Variable: S                    Importance: 0.0
# Variable: ZRO2                 Importance: 0.0
# Variable: AS                   Importance: 0.0
# [Parallel(n_jobs=4)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  42 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=4)]: Done  50 out of  50 | elapsed:    0.0s finished
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 4 concurrent workers.
# 0.8518518518518519
# Training .... FELDSPAR
# Average number of nodes 86
# Average maximum depth 9
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done  50 out of  50 | elapsed:    0.0s finished
# [Parallel(n_jobs=4)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  42 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=4)]: Done  50 out of  50 | elapsed:    0.0s finished
# Variable: NA2O                 Importance: 0.19
# Variable: CAO                  Importance: 0.14
# Variable: SIO2                 Importance: 0.13
# Variable: AL2O3                Importance: 0.13
# Variable: K2O                  Importance: 0.12
# Variable: FEOT                 Importance: 0.06
# Variable: TIO2                 Importance: 0.05
# Variable: MGO                  Importance: 0.03
# Variable: F                    Importance: 0.03
# Variable: CL                   Importance: 0.03
# Variable: CR2O3                Importance: 0.02
# Variable: MNO                  Importance: 0.02
# Variable: P2O5                 Importance: 0.02
# Variable: NIO                  Importance: 0.02
# Variable: H20                  Importance: 0.0
# Variable: CUO                  Importance: 0.0
# Variable: COO                  Importance: 0.0
# Variable: ZNO                  Importance: 0.0
# Variable: PBO                  Importance: 0.0
# Variable: S                    Importance: 0.0
# Variable: ZRO2                 Importance: 0.0
# Variable: AS                   Importance: 0.0
# Normalized confusion matrix
#               precision    recall  f1-score   support
#
#       ALBITE       0.90      1.00      0.95         9
#     ANDESINE       1.00      0.67      0.80         9
#    ANORTHITE       0.88      0.78      0.82         9
# ANORTHOCLASE       0.75      1.00      0.86         9
#    BYTOWNITE       0.73      0.89      0.80         9
#  LABRADORITE       0.78      0.78      0.78         9
#   MICROCLINE       0.88      0.78      0.82         9
#   OLIGOCLASE       0.89      0.89      0.89         9
#   ORTHOCLASE       0.78      0.78      0.78         9
#     SANIDINE       0.88      0.78      0.82         9
#
#     accuracy                           0.83        90
#    macro avg       0.84      0.83      0.83        90
# weighted avg       0.84      0.83      0.83        90
#
# 0.8333333333333334
# Average number of nodes 86
# Average maximum depth 9
# Variable: NA2O                 Importance: 0.19
# Variable: CAO                  Importance: 0.14
# Variable: SIO2                 Importance: 0.13
# Variable: AL2O3                Importance: 0.13
# Variable: K2O                  Importance: 0.12
# Variable: FEOT                 Importance: 0.06
# Variable: TIO2                 Importance: 0.05
# Variable: MGO                  Importance: 0.03
# Variable: F                    Importance: 0.03
# Variable: CL                   Importance: 0.03
# Variable: CR2O3                Importance: 0.02
# Variable: MNO                  Importance: 0.02
# Variable: P2O5                 Importance: 0.02
# Variable: NIO                  Importance: 0.02
# Variable: H20                  Importance: 0.0
# Variable: CUO                  Importance: 0.0
# Variable: COO                  Importance: 0.0
# Variable: ZNO                  Importance: 0.0
# Variable: PBO                  Importance: 0.0
# Variable: S                    Importance: 0.0
# Variable: ZRO2                 Importance: 0.0
# Variable: AS                   Importance: 0.0
# [Parallel(n_jobs=4)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  42 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=4)]: Done  50 out of  50 | elapsed:    0.0s finished
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 4 concurrent workers.
# 0.8333333333333334
# Training .... FELDSPATHOID
# Average number of nodes 79
# Average maximum depth 10
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done  50 out of  50 | elapsed:    0.0s finished
# [Parallel(n_jobs=4)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  42 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=4)]: Done  50 out of  50 | elapsed:    0.0s finished
# Variable: SIO2                 Importance: 0.15
# Variable: K2O                  Importance: 0.15
# Variable: NA2O                 Importance: 0.11
# Variable: AL2O3                Importance: 0.09
# Variable: CAO                  Importance: 0.09
# Variable: CL                   Importance: 0.08
# Variable: FEOT                 Importance: 0.06
# Variable: P2O5                 Importance: 0.06
# Variable: MGO                  Importance: 0.04
# Variable: H20                  Importance: 0.04
# Variable: TIO2                 Importance: 0.03
# Variable: S                    Importance: 0.03
# Variable: CR2O3                Importance: 0.02
# Variable: MNO                  Importance: 0.02
# Variable: F                    Importance: 0.02
# Variable: NIO                  Importance: 0.02
# Variable: CUO                  Importance: 0.0
# Variable: COO                  Importance: 0.0
# Variable: ZNO                  Importance: 0.0
# Variable: PBO                  Importance: 0.0
# Variable: ZRO2                 Importance: 0.0
# Variable: AS                   Importance: 0.0
# Normalized confusion matrix
#                precision    recall  f1-score   support
#
#      ANALCIME       1.00      0.89      0.94         9
#    CANCRINITE       0.78      0.78      0.78         9
#        HAUYNE       0.67      0.89      0.76         9
#  KALIOPHILITE       1.00      1.00      1.00         9
#     KALSILITE       1.00      1.00      1.00         9
#       LEUCITE       1.00      1.00      1.00         9
#     NEPHELINE       1.00      0.89      0.94         9
#        NOSEAN       0.89      0.89      0.89         9
# PSEUDOLEUCITE       0.90      1.00      0.95         9
#      SODALITE       0.86      0.67      0.75         9
#    VISHNEVITE       1.00      1.00      1.00         9
#
#      accuracy                           0.91        99
#     macro avg       0.92      0.91      0.91        99
#  weighted avg       0.92      0.91      0.91        99
#
# 0.9090909090909091
# Average number of nodes 79
# Average maximum depth 10
# Variable: SIO2                 Importance: 0.15
# Variable: K2O                  Importance: 0.15
# Variable: NA2O                 Importance: 0.11
# Variable: AL2O3                Importance: 0.09
# Variable: CAO                  Importance: 0.09
# Variable: CL                   Importance: 0.08
# Variable: FEOT                 Importance: 0.06
# Variable: P2O5                 Importance: 0.06
# Variable: MGO                  Importance: 0.04
# Variable: H20                  Importance: 0.04
# Variable: TIO2                 Importance: 0.03
# Variable: S                    Importance: 0.03
# Variable: CR2O3                Importance: 0.02
# Variable: MNO                  Importance: 0.02
# Variable: F                    Importance: 0.02
# Variable: NIO                  Importance: 0.02
# Variable: CUO                  Importance: 0.0
# Variable: COO                  Importance: 0.0
# Variable: ZNO                  Importance: 0.0
# Variable: PBO                  Importance: 0.0
# Variable: ZRO2                 Importance: 0.0
# Variable: AS                   Importance: 0.0
# [Parallel(n_jobs=4)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  42 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=4)]: Done  50 out of  50 | elapsed:    0.0s finished
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 4 concurrent workers.
# 0.9090909090909091
# Training .... GARNET
# Average number of nodes 55
# Average maximum depth 9
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done  50 out of  50 | elapsed:    0.0s finished
# [Parallel(n_jobs=4)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  42 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=4)]: Done  50 out of  50 | elapsed:    0.0s finished
# Variable: SIO2                 Importance: 0.11
# Variable: AL2O3                Importance: 0.11
# Variable: FEOT                 Importance: 0.1
# Variable: MGO                  Importance: 0.09
# Variable: CAO                  Importance: 0.08
# Variable: TIO2                 Importance: 0.07
# Variable: ZRO2                 Importance: 0.07
# Variable: MNO                  Importance: 0.06
# Variable: CL                   Importance: 0.06
# Variable: CR2O3                Importance: 0.04
# Variable: NA2O                 Importance: 0.04
# Variable: H20                  Importance: 0.04
# Variable: F                    Importance: 0.04
# Variable: NIO                  Importance: 0.04
# Variable: P2O5                 Importance: 0.03
# Variable: K2O                  Importance: 0.02
# Variable: ZNO                  Importance: 0.02
# Variable: CUO                  Importance: 0.0
# Variable: COO                  Importance: 0.0
# Variable: PBO                  Importance: 0.0
# Variable: S                    Importance: 0.0
# Variable: AS                   Importance: 0.0
# Normalized confusion matrix
#               precision    recall  f1-score   support
#
#    ALMANDINE       0.90      1.00      0.95         9
#    ANDRADITE       0.78      0.78      0.78         9
#    GROSSULAR       1.00      1.00      1.00         9
#    HIBSCHITE       1.00      1.00      1.00         9
#  HYDROGARNET       0.75      1.00      0.86         9
#     MELANITE       0.75      0.33      0.46         9
#       PYROPE       0.90      1.00      0.95         9
#  SCHORLOMITE       0.89      0.89      0.89         9
#
#     accuracy                           0.88        72
#    macro avg       0.87      0.88      0.86        72
# weighted avg       0.87      0.88      0.86        72
#
# 0.875
# Average number of nodes 55
# Average maximum depth 9
# Variable: SIO2                 Importance: 0.11
# Variable: AL2O3                Importance: 0.11
# Variable: FEOT                 Importance: 0.1
# Variable: MGO                  Importance: 0.09
# Variable: CAO                  Importance: 0.08
# Variable: TIO2                 Importance: 0.07
# Variable: ZRO2                 Importance: 0.07
# Variable: MNO                  Importance: 0.06
# Variable: CL                   Importance: 0.06
# Variable: CR2O3                Importance: 0.04
# Variable: NA2O                 Importance: 0.04
# Variable: H20                  Importance: 0.04
# Variable: F                    Importance: 0.04
# Variable: NIO                  Importance: 0.04
# Variable: P2O5                 Importance: 0.03
# Variable: K2O                  Importance: 0.02
# Variable: ZNO                  Importance: 0.02
# Variable: CUO                  Importance: 0.0
# Variable: COO                  Importance: 0.0
# Variable: PBO                  Importance: 0.0
# Variable: S                    Importance: 0.0
# Variable: AS                   Importance: 0.0
# [Parallel(n_jobs=4)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  42 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=4)]: Done  50 out of  50 | elapsed:    0.0s finished
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 4 concurrent workers.
# 0.875
# Training .... MICA
# Average number of nodes 124
# Average maximum depth 11
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done  50 out of  50 | elapsed:    0.0s finished
# [Parallel(n_jobs=4)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  42 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=4)]: Done  50 out of  50 | elapsed:    0.0s finished
# Variable: AL2O3                Importance: 0.12
# Variable: MGO                  Importance: 0.12
# Variable: TIO2                 Importance: 0.09
# Variable: F                    Importance: 0.09
# Variable: FEOT                 Importance: 0.08
# Variable: SIO2                 Importance: 0.07
# Variable: H20                  Importance: 0.07
# Variable: MNO                  Importance: 0.06
# Variable: K2O                  Importance: 0.06
# Variable: CAO                  Importance: 0.05
# Variable: NA2O                 Importance: 0.05
# Variable: CL                   Importance: 0.05
# Variable: NIO                  Importance: 0.04
# Variable: CR2O3                Importance: 0.03
# Variable: P2O5                 Importance: 0.03
# Variable: CUO                  Importance: 0.0
# Variable: COO                  Importance: 0.0
# Variable: ZNO                  Importance: 0.0
# Variable: PBO                  Importance: 0.0
# Variable: S                    Importance: 0.0
# Variable: ZRO2                 Importance: 0.0
# Variable: AS                   Importance: 0.0
# Normalized confusion matrix
#                     precision    recall  f1-score   support
#
#             ANNITE       0.89      0.89      0.89         9
#            BIOTITE       0.90      1.00      0.95         9
#         CELADONITE       1.00      0.89      0.94         9
#         GLAUCONITE       0.90      1.00      0.95         9
#          HYDROMICA       1.00      1.00      1.00         9
#     HYDROMUSCOVITE       0.89      0.89      0.89         9
#         LEPIDOLITE       1.00      0.89      0.94         9
#          MARGARITE       1.00      1.00      1.00         9
#          MUSCOVITE       1.00      1.00      1.00         9
#         PARAGONITE       1.00      0.89      0.94         9
#           PHENGITE       0.90      1.00      0.95         9
# PHENGITE-MUSCOVITE       0.90      1.00      0.95         9
#         PHLOGOPITE       1.00      0.89      0.94         9
#           SERICITE       1.00      1.00      1.00         9
#     SIDEROPHYLLITE       1.00      1.00      1.00         9
#     YANGZHUMINGITE       1.00      1.00      1.00         9
#        ZINNWALDITE       1.00      1.00      1.00         9
#
#           accuracy                           0.96       153
#          macro avg       0.96      0.96      0.96       153
#       weighted avg       0.96      0.96      0.96       153
#
# 0.9607843137254902
# Average number of nodes 124
# Average maximum depth 11
# Variable: AL2O3                Importance: 0.12
# Variable: MGO                  Importance: 0.12
# Variable: TIO2                 Importance: 0.09
# Variable: F                    Importance: 0.09
# Variable: FEOT                 Importance: 0.08
# Variable: SIO2                 Importance: 0.07
# Variable: H20                  Importance: 0.07
# Variable: MNO                  Importance: 0.06
# Variable: K2O                  Importance: 0.06
# Variable: CAO                  Importance: 0.05
# Variable: NA2O                 Importance: 0.05
# Variable: CL                   Importance: 0.05
# Variable: NIO                  Importance: 0.04
# Variable: CR2O3                Importance: 0.03
# Variable: P2O5                 Importance: 0.03
# Variable: CUO                  Importance: 0.0
# Variable: COO                  Importance: 0.0
# Variable: ZNO                  Importance: 0.0
# Variable: PBO                  Importance: 0.0
# Variable: S                    Importance: 0.0
# Variable: ZRO2                 Importance: 0.0
# Variable: AS                   Importance: 0.0
# [Parallel(n_jobs=4)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  42 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=4)]: Done  50 out of  50 | elapsed:    0.0s finished
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 4 concurrent workers.
# 0.9607843137254902
# Training .... OLIVINE
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done  50 out of  50 | elapsed:    0.0s finished
# Average number of nodes 25
# Average maximum depth 6
# Variable: MGO                  Importance: 0.15
# Variable: MNO                  Importance: 0.14
# Variable: SIO2                 Importance: 0.11
# Variable: FEOT                 Importance: 0.1
# Variable: K2O                  Importance: 0.1
# Variable: NIO                  Importance: 0.1
# Variable: NA2O                 Importance: 0.09
# Variable: TIO2                 Importance: 0.04
# Variable: AL2O3                Importance: 0.04
# Variable: CR2O3                Importance: 0.04
# Variable: P2O5                 Importance: 0.04
# Variable: CAO                  Importance: 0.03
# Variable: H20                  Importance: 0.01
# Variable: F                    Importance: 0.0
# Variable: CL                   Importance: 0.0
# Variable: CUO                  Importance: 0.0
# Variable: COO                  Importance: 0.0
# Variable: ZNO                  Importance: 0.0
# Variable: PBO                  Importance: 0.0
# Variable: S                    Importance: 0.0
# Variable: ZRO2                 Importance: 0.0
# Variable: AS                   Importance: 0.0
# [Parallel(n_jobs=4)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  42 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=4)]: Done  50 out of  50 | elapsed:    0.0s finished
# Normalized confusion matrix
#               precision    recall  f1-score   support
#
#     FAYALITE       1.00      1.00      1.00         9
#   FORSTERITE       1.00      0.89      0.94         9
#   IDDINGSITE       0.89      0.89      0.89         9
# MONTICELLITE       0.89      0.89      0.89         9
#  RINGWOODITE       0.90      1.00      0.95         9
#
#     accuracy                           0.93        45
#    macro avg       0.94      0.93      0.93        45
# weighted avg       0.94      0.93      0.93        45
#
# 0.9333333333333333
# Average number of nodes 25
# Average maximum depth 6
# Variable: MGO                  Importance: 0.15
# Variable: MNO                  Importance: 0.14
# Variable: SIO2                 Importance: 0.11
# Variable: FEOT                 Importance: 0.1
# Variable: K2O                  Importance: 0.1
# Variable: NIO                  Importance: 0.1
# Variable: NA2O                 Importance: 0.09
# Variable: TIO2                 Importance: 0.04
# Variable: AL2O3                Importance: 0.04
# Variable: CR2O3                Importance: 0.04
# Variable: P2O5                 Importance: 0.04
# Variable: CAO                  Importance: 0.03
# Variable: H20                  Importance: 0.01
# Variable: F                    Importance: 0.0
# Variable: CL                   Importance: 0.0
# Variable: CUO                  Importance: 0.0
# Variable: COO                  Importance: 0.0
# Variable: ZNO                  Importance: 0.0
# Variable: PBO                  Importance: 0.0
# Variable: S                    Importance: 0.0
# Variable: ZRO2                 Importance: 0.0
# Variable: AS                   Importance: 0.0
# [Parallel(n_jobs=4)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  42 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=4)]: Done  50 out of  50 | elapsed:    0.0s finished
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 4 concurrent workers.
# 0.9333333333333333
# Training .... PYROXENE
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done  50 out of  50 | elapsed:    0.0s finished
# Average number of nodes 164
# Average maximum depth 12
# Variable: CAO                  Importance: 0.12
# Variable: MGO                  Importance: 0.12
# Variable: FEOT                 Importance: 0.1
# Variable: NA2O                 Importance: 0.09
# Variable: AL2O3                Importance: 0.08
# Variable: MNO                  Importance: 0.08
# Variable: SIO2                 Importance: 0.07
# Variable: TIO2                 Importance: 0.05
# Variable: CR2O3                Importance: 0.05
# Variable: K2O                  Importance: 0.04
# Variable: ZRO2                 Importance: 0.04
# Variable: P2O5                 Importance: 0.03
# Variable: COO                  Importance: 0.03
# Variable: CL                   Importance: 0.02
# Variable: NIO                  Importance: 0.02
# Variable: ZNO                  Importance: 0.02
# Variable: H20                  Importance: 0.01
# Variable: F                    Importance: 0.0
# Variable: CUO                  Importance: 0.0
# Variable: PBO                  Importance: 0.0
# Variable: S                    Importance: 0.0
# Variable: AS                   Importance: 0.0
# [Parallel(n_jobs=4)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  42 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=4)]: Done  50 out of  50 | elapsed:    0.0s finished
# Normalized confusion matrix
#                    precision    recall  f1-score   support
#
#            ACMITE       1.00      1.00      1.00         9
#          AEGIRINE       0.90      1.00      0.95         9
#            AUGITE       0.88      0.78      0.82         9
#    CLINOENSTATITE       1.00      0.78      0.88         9
#       CR-DIOPSIDE       0.78      0.78      0.78         9
#          DIOPSIDE       0.58      0.78      0.67         9
#         ENSTATITE       0.80      0.89      0.84         9
#          FASSAITE       0.80      0.44      0.57         9
#       FE-DIOPSIDE       1.00      0.89      0.94         9
#       FERROAUGITE       1.00      0.78      0.88         9
# FERROHEDENBERGITE       0.73      0.89      0.80         9
#    FERROPIGEONITE       0.86      0.67      0.75         9
#       FERROSILITE       1.00      0.78      0.88         9
#      HEDENBERGITE       0.89      0.89      0.89         9
#       HYPERSTHENE       0.90      1.00      0.95         9
#           JADEITE       0.67      0.89      0.76         9
#         OMPHACITE       1.00      1.00      1.00         9
#         PIGEONITE       0.46      0.67      0.55         9
#            SALITE       0.82      1.00      0.90         9
#      TITAN-AUGITE       0.83      0.56      0.67         9
#
#          accuracy                           0.82       180
#         macro avg       0.84      0.82      0.82       180
#      weighted avg       0.84      0.82      0.82       180
#
# 0.8222222222222222
# Average number of nodes 164
# Average maximum depth 12
# Variable: CAO                  Importance: 0.12
# Variable: MGO                  Importance: 0.12
# Variable: FEOT                 Importance: 0.1
# Variable: NA2O                 Importance: 0.09
# Variable: AL2O3                Importance: 0.08
# Variable: MNO                  Importance: 0.08
# Variable: SIO2                 Importance: 0.07
# Variable: TIO2                 Importance: 0.05
# Variable: CR2O3                Importance: 0.05
# Variable: K2O                  Importance: 0.04
# Variable: ZRO2                 Importance: 0.04
# Variable: P2O5                 Importance: 0.03
# Variable: COO                  Importance: 0.03
# Variable: CL                   Importance: 0.02
# Variable: NIO                  Importance: 0.02
# Variable: ZNO                  Importance: 0.02
# Variable: H20                  Importance: 0.01
# Variable: F                    Importance: 0.0
# Variable: CUO                  Importance: 0.0
# Variable: PBO                  Importance: 0.0
# Variable: S                    Importance: 0.0
# Variable: AS                   Importance: 0.0
# [Parallel(n_jobs=4)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  42 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=4)]: Done  50 out of  50 | elapsed:    0.0s finished
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 4 concurrent workers.
# 0.8222222222222222
# Training .... SPINEL
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done  50 out of  50 | elapsed:    0.1s finished
# Average number of nodes 118
# Average maximum depth 10
# Variable: AL2O3                Importance: 0.13
# Variable: CR2O3                Importance: 0.13
# Variable: FEOT                 Importance: 0.11
# Variable: MGO                  Importance: 0.1
# Variable: MNO                  Importance: 0.1
# Variable: TIO2                 Importance: 0.08
# Variable: CAO                  Importance: 0.07
# Variable: NIO                  Importance: 0.07
# Variable: ZNO                  Importance: 0.07
# Variable: SIO2                 Importance: 0.04
# Variable: K2O                  Importance: 0.04
# Variable: NA2O                 Importance: 0.04
# Variable: P2O5                 Importance: 0.03
# Variable: H20                  Importance: 0.0
# Variable: F                    Importance: 0.0
# Variable: CL                   Importance: 0.0
# Variable: CUO                  Importance: 0.0
# Variable: COO                  Importance: 0.0
# Variable: PBO                  Importance: 0.0
# Variable: S                    Importance: 0.0
# Variable: ZRO2                 Importance: 0.0
# Variable: AS                   Importance: 0.0
# [Parallel(n_jobs=4)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  42 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=4)]: Done  50 out of  50 | elapsed:    0.0s finished
# Normalized confusion matrix
#                   precision    recall  f1-score   support
#
#        AL-SPINEL       0.56      0.56      0.56         9
#    CHROME-SPINEL       0.86      0.67      0.75         9
#         CHROMITE       0.70      0.78      0.74         9
#      FE-CHROMITE       0.82      1.00      0.90         9
#          GAHNITE       1.00      0.78      0.88         9
#        HERCYNITE       1.00      0.78      0.88         9
#  MAGNESIOFERRITE       0.82      1.00      0.90         9
#        MAGNETITE       0.54      0.78      0.64         9
#        PLEONASTE       0.64      0.78      0.70         9
# TITANO-MAGNETITE       1.00      0.22      0.36         9
#       ULVOSPINEL       0.73      0.89      0.80         9
#
#         accuracy                           0.75        99
#        macro avg       0.79      0.75      0.74        99
#     weighted avg       0.79      0.75      0.74        99
#
# 0.7474747474747475
# Average number of nodes 118
# Average maximum depth 10
# Variable: AL2O3                Importance: 0.13
# Variable: CR2O3                Importance: 0.13
# Variable: FEOT                 Importance: 0.11
# Variable: MGO                  Importance: 0.1
# Variable: MNO                  Importance: 0.1
# Variable: TIO2                 Importance: 0.08
# Variable: CAO                  Importance: 0.07
# Variable: NIO                  Importance: 0.07
# Variable: ZNO                  Importance: 0.07
# Variable: SIO2                 Importance: 0.04
# Variable: K2O                  Importance: 0.04
# Variable: NA2O                 Importance: 0.04
# Variable: P2O5                 Importance: 0.03
# Variable: H20                  Importance: 0.0
# Variable: F                    Importance: 0.0
# Variable: CL                   Importance: 0.0
# Variable: CUO                  Importance: 0.0
# Variable: COO                  Importance: 0.0
# Variable: PBO                  Importance: 0.0
# Variable: S                    Importance: 0.0
# Variable: ZRO2                 Importance: 0.0
# Variable: AS                   Importance: 0.0
# [Parallel(n_jobs=4)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  42 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=4)]: Done  50 out of  50 | elapsed:    0.0s finished
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 4 concurrent workers.
# 0.7474747474747475
# Training .... SULFIDE
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done  50 out of  50 | elapsed:    0.0s finished
# Average number of nodes 265
# Average maximum depth 17
# Variable: S                    Importance: 0.16
# Variable: FEOT                 Importance: 0.15
# Variable: NIO                  Importance: 0.14
# Variable: CUO                  Importance: 0.12
# Variable: COO                  Importance: 0.11
# Variable: AS                   Importance: 0.1
# Variable: ZNO                  Importance: 0.07
# Variable: PBO                  Importance: 0.07
# Variable: CAO                  Importance: 0.03
# Variable: K2O                  Importance: 0.03
# Variable: NA2O                 Importance: 0.02
# Variable: SIO2                 Importance: 0.0
# Variable: TIO2                 Importance: 0.0
# Variable: AL2O3                Importance: 0.0
# Variable: CR2O3                Importance: 0.0
# Variable: MGO                  Importance: 0.0
# Variable: MNO                  Importance: 0.0
# Variable: P2O5                 Importance: 0.0
# Variable: H20                  Importance: 0.0
# Variable: F                    Importance: 0.0
# Variable: CL                   Importance: 0.0
# Variable: ZRO2                 Importance: 0.0
# [Parallel(n_jobs=4)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  42 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=4)]: Done  50 out of  50 | elapsed:    0.0s finished
# Normalized confusion matrix
#                          precision    recall  f1-score   support
#
#              ALABANDITE       0.89      0.89      0.89         9
#            ARSENOPYRITE       1.00      0.89      0.94         9
#                 BORNITE       1.00      0.78      0.88         9
#              CHALCOCITE       1.00      1.00      1.00         9
#            CHALCOPYRITE       0.86      0.67      0.75         9
#          CHLORBARTONITE       0.67      0.67      0.67         9
#               COBALTITE       1.00      1.00      1.00         9
#                CUBANITE       0.80      0.89      0.84         9
#                  GALENA       1.00      1.00      1.00         9
#            GERSDORFFITE       1.00      1.00      1.00         9
#             GODLEVSKITE       1.00      1.00      1.00         9
#             GUANGLINITE       1.00      1.00      1.00         9
#           HEAZLEWOODITE       1.00      1.00      1.00         9
# HEXATESTIBIOPANICKELITE       1.00      1.00      1.00         9
#         HOLLINGWORTHITE       1.00      1.00      1.00         9
#                IRARSITE       1.00      1.00      1.00         9
#             ISOCUBANITE       0.64      0.78      0.70         9
#               LINNAEITE       1.00      1.00      1.00         9
#             MACKINAWITE       0.73      0.89      0.80         9
#              MAUCHERITE       1.00      1.00      1.00         9
#             MERENSKYITE       0.88      0.78      0.82         9
#             MOLYBDENITE       1.00      1.00      1.00         9
#               NICKELINE       1.00      1.00      1.00         9
#               PARKERITE       1.00      1.00      1.00         9
#             PENTLANDITE       0.88      0.78      0.82         9
#              POLYDYMITE       1.00      1.00      1.00         9
#                  PYRITE       0.90      1.00      0.95         9
#              PYRRHOTITE       1.00      0.78      0.88         9
#               RASVUMITE       0.80      0.89      0.84         9
#              SPHALERITE       0.73      0.89      0.80         9
#            STROMEYERITE       1.00      1.00      1.00         9
#
#                accuracy                           0.92       279
#               macro avg       0.93      0.92      0.92       279
#            weighted avg       0.93      0.92      0.92       279
#
# 0.921146953405018
# Average number of nodes 265
# Average maximum depth 17
# Variable: S                    Importance: 0.16
# Variable: FEOT                 Importance: 0.15
# Variable: NIO                  Importance: 0.14
# Variable: CUO                  Importance: 0.12
# Variable: COO                  Importance: 0.11
# Variable: AS                   Importance: 0.1
# Variable: ZNO                  Importance: 0.07
# Variable: PBO                  Importance: 0.07
# Variable: CAO                  Importance: 0.03
# Variable: K2O                  Importance: 0.03
# Variable: NA2O                 Importance: 0.02
# Variable: SIO2                 Importance: 0.0
# Variable: TIO2                 Importance: 0.0
# Variable: AL2O3                Importance: 0.0
# Variable: CR2O3                Importance: 0.0
# Variable: MGO                  Importance: 0.0
# Variable: MNO                  Importance: 0.0
# Variable: P2O5                 Importance: 0.0
# Variable: H20                  Importance: 0.0
# Variable: F                    Importance: 0.0
# Variable: CL                   Importance: 0.0
# Variable: ZRO2                 Importance: 0.0
# [Parallel(n_jobs=4)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  42 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=4)]: Done  50 out of  50 | elapsed:    0.0s finished
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 4 concurrent workers.
# 0.921146953405018
# Training .... APATITE
# Average number of nodes 1
# Average maximum depth 0
# Variable: SIO2                 Importance: 0.0
# Variable: TIO2                 Importance: 0.0
# Variable: AL2O3                Importance: 0.0
# Variable: CR2O3                Importance: 0.0
# Variable: FEOT                 Importance: 0.0
# Variable: CAO                  Importance: 0.0
# Variable: MGO                  Importance: 0.0
# Variable: MNO                  Importance: 0.0
# ...
# [Parallel(n_jobs=4)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  42 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=4)]: Done  50 out of  50 | elapsed:    0.0s finished
# Average number of nodes 1
# Average maximum depth 0
# Variable: SIO2                 Importance: 0.0
# Variable: TIO2                 Importance: 0.0
# Variable: AL2O3                Importance: 0.0
# Variable: CR2O3                Importance: 0.0
# Variable: FEOT                 Importance: 0.0
# Variable: CAO                  Importance: 0.0
# Variable: MGO                  Importance: 0.0
# Variable: MNO                  Importance: 0.0
# Variable: K2O                  Importance: 0.0
# Variable: NA2O                 Importance: 0.0
# Variable: P2O5                 Importance: 0.0
# Variable: H20                  Importance: 0.0
# Variable: F                    Importance: 0.0
# Variable: CL                   Importance: 0.0
# Variable: NIO                  Importance: 0.0
# Variable: CUO                  Importance: 0.0
# Variable: COO                  Importance: 0.0
# Variable: ZNO                  Importance: 0.0
# Variable: PBO                  Importance: 0.0
# Variable: S                    Importance: 0.0
# Variable: ZRO2                 Importance: 0.0
# Variable: AS                   Importance: 0.0
# Normalized confusion matrix
#               precision    recall  f1-score   support
#
#     ILMENITE       1.00      1.00      1.00         9
#
#     accuracy                           1.00         9
#    macro avg       1.00      1.00      1.00         9
# weighted avg       1.00      1.00      1.00         9
#
# 1.0
# Average number of nodes 1
# Average maximum depth 0
# Variable: SIO2                 Importance: 0.0
# Variable: TIO2                 Importance: 0.0
# Variable: AL2O3                Importance: 0.0
# Variable: CR2O3                Importance: 0.0
# Variable: FEOT                 Importance: 0.0
# Variable: CAO                  Importance: 0.0
# Variable: MGO                  Importance: 0.0
# Variable: MNO                  Importance: 0.0
# Variable: K2O                  Importance: 0.0
# Variable: NA2O                 Importance: 0.0
# Variable: P2O5                 Importance: 0.0
# Variable: H20                  Importance: 0.0
# Variable: F                    Importance: 0.0
# Variable: CL                   Importance: 0.0
# Variable: NIO                  Importance: 0.0
# Variable: CUO                  Importance: 0.0
# Variable: COO                  Importance: 0.0
# Variable: ZNO                  Importance: 0.0
# Variable: PBO                  Importance: 0.0
# Variable: S                    Importance: 0.0
# Variable: ZRO2                 Importance: 0.0
# Variable: AS                   Importance: 0.0
# 1.0
# Training .... PEROVSKITE
# [Parallel(n_jobs=4)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  42 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=4)]: Done  50 out of  50 | elapsed:    0.0s finished
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done  50 out of  50 | elapsed:    0.0s finished
# [Parallel(n_jobs=4)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  42 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=4)]: Done  50 out of  50 | elapsed:    0.0s finished
# Average number of nodes 1
# Average maximum depth 0
# Variable: SIO2                 Importance: 0.0
# Variable: TIO2                 Importance: 0.0
# Variable: AL2O3                Importance: 0.0
# Variable: CR2O3                Importance: 0.0
# Variable: FEOT                 Importance: 0.0
# Variable: CAO                  Importance: 0.0
# Variable: MGO                  Importance: 0.0
# Variable: MNO                  Importance: 0.0
# Variable: K2O                  Importance: 0.0
# Variable: NA2O                 Importance: 0.0
# Variable: P2O5                 Importance: 0.0
# Variable: H20                  Importance: 0.0
# Variable: F                    Importance: 0.0
# Variable: CL                   Importance: 0.0
# Variable: NIO                  Importance: 0.0
# Variable: CUO                  Importance: 0.0
# Variable: COO                  Importance: 0.0
# Variable: ZNO                  Importance: 0.0
# Variable: PBO                  Importance: 0.0
# Variable: S                    Importance: 0.0
# Variable: ZRO2                 Importance: 0.0
# Variable: AS                   Importance: 0.0
# Normalized confusion matrix
#               precision    recall  f1-score   support
#
#   PEROVSKITE       1.00      1.00      1.00         9
#
#     accuracy                           1.00         9
#    macro avg       1.00      1.00      1.00         9
# weighted avg       1.00      1.00      1.00         9
#
# 1.0
# Average number of nodes 1
# Average maximum depth 0
# Variable: SIO2                 Importance: 0.0
# Variable: TIO2                 Importance: 0.0
# Variable: AL2O3                Importance: 0.0
# Variable: CR2O3                Importance: 0.0
# Variable: FEOT                 Importance: 0.0
# Variable: CAO                  Importance: 0.0
# Variable: MGO                  Importance: 0.0
# Variable: MNO                  Importance: 0.0
# Variable: K2O                  Importance: 0.0
# Variable: NA2O                 Importance: 0.0
# Variable: P2O5                 Importance: 0.0
# Variable: H20                  Importance: 0.0
# Variable: F                    Importance: 0.0
# Variable: CL                   Importance: 0.0
# Variable: NIO                  Importance: 0.0
# Variable: CUO                  Importance: 0.0
# Variable: COO                  Importance: 0.0
# Variable: ZNO                  Importance: 0.0
# Variable: PBO                  Importance: 0.0
# Variable: S                    Importance: 0.0
# Variable: ZRO2                 Importance: 0.0
# Variable: AS                   Importance: 0.0
# 1.0
# Training .... QUARTZ
# [Parallel(n_jobs=4)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  42 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=4)]: Done  50 out of  50 | elapsed:    0.0s finished
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done  50 out of  50 | elapsed:    0.0s finished
# [Parallel(n_jobs=4)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  42 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=4)]: Done  50 out of  50 | elapsed:    0.0s finished
# Average number of nodes 1
# Average maximum depth 0
# Variable: SIO2                 Importance: 0.0
# Variable: TIO2                 Importance: 0.0
# Variable: AL2O3                Importance: 0.0
# Variable: CR2O3                Importance: 0.0
# Variable: FEOT                 Importance: 0.0
# Variable: CAO                  Importance: 0.0
# Variable: MGO                  Importance: 0.0
# Variable: MNO                  Importance: 0.0
# Variable: K2O                  Importance: 0.0
# Variable: NA2O                 Importance: 0.0
# Variable: P2O5                 Importance: 0.0
# Variable: H20                  Importance: 0.0
# Variable: F                    Importance: 0.0
# Variable: CL                   Importance: 0.0
# Variable: NIO                  Importance: 0.0
# Variable: CUO                  Importance: 0.0
# Variable: COO                  Importance: 0.0
# Variable: ZNO                  Importance: 0.0
# Variable: PBO                  Importance: 0.0
# Variable: S                    Importance: 0.0
# Variable: ZRO2                 Importance: 0.0
# Variable: AS                   Importance: 0.0
# Normalized confusion matrix
#               precision    recall  f1-score   support
#
#       QUARTZ       1.00      1.00      1.00         9
#
#     accuracy                           1.00         9
#    macro avg       1.00      1.00      1.00         9
# weighted avg       1.00      1.00      1.00         9
#
# 1.0
# Average number of nodes 1
# Average maximum depth 0
# Variable: SIO2                 Importance: 0.0
# Variable: TIO2                 Importance: 0.0
# Variable: AL2O3                Importance: 0.0
# Variable: CR2O3                Importance: 0.0
# Variable: FEOT                 Importance: 0.0
# Variable: CAO                  Importance: 0.0
# Variable: MGO                  Importance: 0.0
# Variable: MNO                  Importance: 0.0
# Variable: K2O                  Importance: 0.0
# Variable: NA2O                 Importance: 0.0
# Variable: P2O5                 Importance: 0.0
# Variable: H20                  Importance: 0.0
# Variable: F                    Importance: 0.0
# Variable: CL                   Importance: 0.0
# Variable: NIO                  Importance: 0.0
# Variable: CUO                  Importance: 0.0
# Variable: COO                  Importance: 0.0
# Variable: ZNO                  Importance: 0.0
# Variable: PBO                  Importance: 0.0
# Variable: S                    Importance: 0.0
# Variable: ZRO2                 Importance: 0.0
# Variable: AS                   Importance: 0.0
# 1.0
# Training .... TITANITE
# [Parallel(n_jobs=4)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  42 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=4)]: Done  50 out of  50 | elapsed:    0.0s finished
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done  50 out of  50 | elapsed:    0.0s finished
# [Parallel(n_jobs=4)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  42 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=4)]: Done  50 out of  50 | elapsed:    0.0s finished
# Average number of nodes 1
# Average maximum depth 0
# Variable: SIO2                 Importance: 0.0
# Variable: TIO2                 Importance: 0.0
# Variable: AL2O3                Importance: 0.0
# Variable: CR2O3                Importance: 0.0
# Variable: FEOT                 Importance: 0.0
# Variable: CAO                  Importance: 0.0
# Variable: MGO                  Importance: 0.0
# Variable: MNO                  Importance: 0.0
# Variable: K2O                  Importance: 0.0
# Variable: NA2O                 Importance: 0.0
# Variable: P2O5                 Importance: 0.0
# Variable: H20                  Importance: 0.0
# Variable: F                    Importance: 0.0
# Variable: CL                   Importance: 0.0
# Variable: NIO                  Importance: 0.0
# Variable: CUO                  Importance: 0.0
# Variable: COO                  Importance: 0.0
# Variable: ZNO                  Importance: 0.0
# Variable: PBO                  Importance: 0.0
# Variable: S                    Importance: 0.0
# Variable: ZRO2                 Importance: 0.0
# Variable: AS                   Importance: 0.0
# Normalized confusion matrix
#                    precision    recall  f1-score   support
#
# TITANITE (SPHENE)       1.00      1.00      1.00         9
#
#          accuracy                           1.00         9
#         macro avg       1.00      1.00      1.00         9
#      weighted avg       1.00      1.00      1.00         9
#
# 1.0
# Average number of nodes 1
# Average maximum depth 0
# Variable: SIO2                 Importance: 0.0
# Variable: TIO2                 Importance: 0.0
# Variable: AL2O3                Importance: 0.0
# Variable: CR2O3                Importance: 0.0
# Variable: FEOT                 Importance: 0.0
# Variable: CAO                  Importance: 0.0
# Variable: MGO                  Importance: 0.0
# Variable: MNO                  Importance: 0.0
# Variable: K2O                  Importance: 0.0
# Variable: NA2O                 Importance: 0.0
# Variable: P2O5                 Importance: 0.0
# Variable: H20                  Importance: 0.0
# Variable: F                    Importance: 0.0
# Variable: CL                   Importance: 0.0
# Variable: NIO                  Importance: 0.0
# Variable: CUO                  Importance: 0.0
# Variable: COO                  Importance: 0.0
# Variable: ZNO                  Importance: 0.0
# Variable: PBO                  Importance: 0.0
# Variable: S                    Importance: 0.0
# Variable: ZRO2                 Importance: 0.0
# Variable: AS                   Importance: 0.0
# 1.0
# Training .... ZIRCON
# [Parallel(n_jobs=4)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  42 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=4)]: Done  50 out of  50 | elapsed:    0.0s finished
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done  50 out of  50 | elapsed:    0.0s finished
# [Parallel(n_jobs=4)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  42 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=4)]: Done  50 out of  50 | elapsed:    0.0s finished
# Average number of nodes 1
# Average maximum depth 0
# Variable: SIO2                 Importance: 0.0
# Variable: TIO2                 Importance: 0.0
# Variable: AL2O3                Importance: 0.0
# Variable: CR2O3                Importance: 0.0
# Variable: FEOT                 Importance: 0.0
# Variable: CAO                  Importance: 0.0
# Variable: MGO                  Importance: 0.0
# Variable: MNO                  Importance: 0.0
# Variable: K2O                  Importance: 0.0
# Variable: NA2O                 Importance: 0.0
# Variable: P2O5                 Importance: 0.0
# Variable: H20                  Importance: 0.0
# Variable: F                    Importance: 0.0
# Variable: CL                   Importance: 0.0
# Variable: NIO                  Importance: 0.0
# Variable: CUO                  Importance: 0.0
# Variable: COO                  Importance: 0.0
# Variable: ZNO                  Importance: 0.0
# Variable: PBO                  Importance: 0.0
# Variable: S                    Importance: 0.0
# Variable: ZRO2                 Importance: 0.0
# Variable: AS                   Importance: 0.0
# Normalized confusion matrix
#               precision    recall  f1-score   support
#
#       ZIRCON       1.00      1.00      1.00         9
#
#     accuracy                           1.00         9
#    macro avg       1.00      1.00      1.00         9
# weighted avg       1.00      1.00      1.00         9
#
# 1.0
# Average number of nodes 1
# Average maximum depth 0
# Variable: SIO2                 Importance: 0.0
# Variable: TIO2                 Importance: 0.0
# Variable: AL2O3                Importance: 0.0
# Variable: CR2O3                Importance: 0.0
# Variable: FEOT                 Importance: 0.0
# Variable: CAO                  Importance: 0.0
# Variable: MGO                  Importance: 0.0
# Variable: MNO                  Importance: 0.0
# Variable: K2O                  Importance: 0.0
# Variable: NA2O                 Importance: 0.0
# Variable: P2O5                 Importance: 0.0
# Variable: H20                  Importance: 0.0
# Variable: F                    Importance: 0.0
# Variable: CL                   Importance: 0.0
# Variable: NIO                  Importance: 0.0
# Variable: CUO                  Importance: 0.0
# Variable: COO                  Importance: 0.0
# Variable: ZNO                  Importance: 0.0
# Variable: PBO                  Importance: 0.0
# Variable: S                    Importance: 0.0
# Variable: ZRO2                 Importance: 0.0
# Variable: AS                   Importance: 0.0
# 1.0
# [['AMPHIBOLES', 0.7777777777777778], ['CARBONATE', 0.8530465949820788], ['CLAY', 0.8518518518518519], ['FELDSPAR', 0.8333333333333334], ['FELDSPATHOID', 0.9090909090909091], ['GARNET', 0.875], ['MICA', 0.9607843137254902], ['OLIVINE', 0.9333333333333333], ['PYROXENE', 0.8222222222222222], ['SPINEL', 0.7474747474747475], ['SULFIDE', 0.921146953405018], ['APATITE', 1.0], ['ILMENITE', 1.0], ['PEROVSKITE', 1.0], ['QUARTZ', 1.0], ['TITANITE', 1.0], ['ZIRCON', 1.0]]
# [Parallel(n_jobs=4)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  42 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=4)]: Done  50 out of  50 | elapsed:    0.0s finished

# %%
def test_cprm_datasets(filename):
    
    #Features used in training!
    Qmin_RF_features = trainFeatures.values.tolist()
    df = pd.read_csv(filename, encoding = "ISO-8859-1")
    df_w = df

    #Remove Columns not in Qmin_Group_RF (Oxides used in trainnig RF model)
    for i in df.columns:
        if i == 'FEO':
            df = df.rename(columns={'FEO':'FEOT'})
            continue
        if i not in Qmin_RF_features:
            print('Data not in trained RF Model: ',i)
            df = df.drop(columns=i)

    # Add missing columns
    for i in Qmin_RF_features:
        if i not in df.columns:
            print('Missing... ', i)
            df[i] = 0.0

    df = df.astype('float64')
    df = df.reindex(columns=Qmin_RF_features)

    group_class = models['GROUP'].predict(df)
    mineral_class = models['SULFIDE'].predict(df)
    df_w['GROUP_ClASS'] = group_class
    df_w['MINERAL_CLASS'] = mineral_class
    df_w.to_csv(filename[:-4]+'_rf_python.csv')
    print(classification_report(df_w['MINERAL'],mineral_class))
    print(accuracy_score(df_w['MINERAL'],mineral_class))

#Teste Anderson
test_cprm_datasets('../data_test/anderson_output.csv')

# %%
# Teste Evandro
test_cprm_datasets('../data_test/evandro_output.csv')
